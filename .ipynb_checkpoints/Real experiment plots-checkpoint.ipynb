# %%
# !python --version
# Out:
# Python 3.7.7

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from pandas.plotting import andrews_curves
import pylab
import pandas as pd
import numpy as np
import warnings
import glob
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Get tables and compute accuracy

# %%
import os
import json

filepath='simulation/query_gt.csv'
if os.path.isfile(filepath):
    print ("Query file exist")
    df = pd.read_csv(filepath,index_col=0)
    queryList = list(df[df['form']=='dnf']['query'])
    indexList = [json.loads(l) for l in list(df[df['form']=='dnf']['index'])]
queryList
# Out:
# Query file exist
# ['(baseball_bat & skis & refrigerator) | wine_glass',
#  'book | person',
#  'cup & person & remote | bird',
#  'handbag & person | train & bicycle',
#  'dining_table | person & clock | handbag',
#  'bus | person | handbag & truck & clock & chair | tennis_racket | sink',
#  'bus & person | cell_phone | bottle',
#  '(book & bird) | traffic_light | bowl',
#  '(bottle & dining_table) | (bowl & couch & car & fork & bench) | cup',
#  'tennis_racket | (spoon & bowl) | tie',
#  '(truck & fork & umbrella & book) | (boat & frisbee) | apple | bottle']

# %%
df.head()
# Out:
#                                                query   len form  \
# 0  (baseball_bat & skis & refrigerator) | wine_glass   110  dnf
# 1                                       cup & person   217  cnf
# 2                                      book | person  2824  dnf
# 3                       cup & person & remote | bird   140  dnf
# 4                 handbag & person | train & bicycle   287  dnf
#
#                                                index
# 0  [25, 28, 33, 41, 42, 75, 79, 161, 181, 184, 20...
# 1  [28, 33, 41, 93, 96, 104, 120, 132, 133, 148, ...
# 2  [0, 2, 5, 7, 8, 9, 10, 11, 12, 14, 17, 19, 22,...
# 3  [10, 34, 41, 101, 104, 133, 156, 176, 189, 225...
# 4  [9, 10, 33, 47, 112, 114, 123, 162, 190, 202, ...

# %%
# identify evaluation set & test set
split_range = 5000*0.4
split_range
# Out:
# 2000.0

# %%
print(indexList[0])
# Out:
# [25, 28, 33, 41, 42, 75, 79, 161, 181, 184, 204, 217, 247, 299, 307, 415, 612, 616, 686, 726, 796, 845, 975, 987, 1188, 1230, 1234, 1235, 1238, 1283, 1285, 1315, 1438, 1474, 1485, 1514, 1535, 1542, 1567, 1577, 1619, 1633, 1660, 1816, 1832, 1851, 1973, 2082, 2130, 2149, 2296, 2318, 2343, 2396, 2547, 2576, 2642, 2704, 2720, 2742, 2866, 2901, 2906, 2924, 2989, 3063, 3095, 3139, 3259, 3295, 3341, 3434, 3474, 3493, 3504, 3562, 3567, 3591, 3597, 3602, 3610, 3614, 3628, 3667, 3756, 3768, 3771, 3803, 3872, 3951, 4071, 4095, 4150, 4167, 4225, 4282, 4314, 4350, 4367, 4429, 4477, 4483, 4563, 4564, 4598, 4657, 4688, 4877, 4926, 4981]

# %% [markdown]
# ## Get runtime

# %%
path = 'results/results_reference.csv'
df_cost = pd.read_csv(path)
df_cost
# Out:
#             experiment       workflow             startedAt  \
# 0   script_yolov3_tiny  sqlflow-gkg4n  2021-06-27T20:09:16Z
# 1   script_yolov3_tiny  sqlflow-ggjhj  2021-06-27T20:09:27Z
# 2   script_yolov3_tiny  sqlflow-rxxp6  2021-06-27T20:09:10Z
# 3       script_yolov5x  sqlflow-zg762  2021-06-28T12:58:44Z
# 4       script_yolov5x  sqlflow-pjhm6  2021-06-27T20:11:03Z
# 5       script_yolov5x  sqlflow-tksxk  2021-06-28T12:58:49Z
# 6       script_yolov5x  sqlflow-vs89b  2021-06-28T12:58:54Z
# 7       script_yolov5x  sqlflow-ft78l  2021-06-27T20:10:58Z
# 8       script_yolov5x  sqlflow-wnbrg  2021-06-27T20:10:52Z
# 9       script_yolov5m  sqlflow-wmgmv  2021-06-27T22:01:25Z
# 10      script_yolov5m  sqlflow-d46w8  2021-06-28T12:51:19Z
# 11      script_yolov5m  sqlflow-dgv6x  2021-06-27T22:01:12Z
# 12      script_yolov5m  sqlflow-bfpz7  2021-06-28T12:51:23Z
# 13      script_yolov5m  sqlflow-s984d  2021-06-28T12:51:14Z
# 14      script_yolov5m  sqlflow-k4fcp  2021-06-27T22:01:21Z
# 15     script_yolov5x6  sqlflow-2v4zx  2021-06-28T13:01:45Z
# 16     script_yolov5x6  sqlflow-sb28p  2021-06-27T20:13:51Z
# 17     script_yolov5x6  sqlflow-5xt6v  2021-06-27T20:13:55Z
# 18     script_yolov5x6  sqlflow-jk4kz  2021-06-28T13:01:41Z
# 19     script_yolov5x6  sqlflow-5vmhg  2021-06-28T13:01:36Z
# 20     script_yolov5x6  sqlflow-vx55g  2021-06-27T20:14:04Z
# 21       script_yolov3  sqlflow-tt94m  2021-06-28T12:48:55Z
# 22       script_yolov3  sqlflow-mks29  2021-06-27T20:06:50Z
# 23       script_yolov3  sqlflow-rtrzt  2021-06-27T20:06:42Z
# 24       script_yolov3  sqlflow-whdxb  2021-06-28T12:49:00Z
# 25       script_yolov3  sqlflow-ld5kh  2021-06-27T20:02:33Z
# 26       script_yolov3  sqlflow-5jb7d  2021-06-27T20:06:55Z
# 27       script_yolov3  sqlflow-k6t9p  2021-06-27T20:02:25Z
# 28       script_yolov3  sqlflow-9hpj4  2021-06-28T12:49:06Z
# 29       script_yolov3  sqlflow-69594  2021-06-27T20:02:20Z
# 30     script_yolov5m6  sqlflow-qdvpj  2021-06-27T22:03:30Z
# 31     script_yolov5m6  sqlflow-zhtb9  2021-06-28T12:53:27Z
# 32     script_yolov5m6  sqlflow-vld6p  2021-06-28T12:53:30Z
# 33     script_yolov5m6  sqlflow-krnx7  2021-06-28T12:53:35Z
# 34     script_yolov5m6  sqlflow-qnkms  2021-06-27T22:03:51Z
# 35     script_yolov5m6  sqlflow-4qdm2  2021-06-27T22:03:40Z
#
#               finishedAt  duration  resourcesDuration_cpu  \
# 0   2021-06-27T20:09:26Z        10                    6.0
# 1   2021-06-27T20:10:47Z        80                  132.0
# 2   2021-06-27T20:09:20Z        10                    1.0
# 3   2021-06-28T12:58:54Z        10                    2.0
# 4   2021-06-27T20:13:47Z       164                  298.0
# 5   2021-06-28T12:58:59Z        10                    1.0
# 6   2021-06-28T13:01:32Z       158                  293.0
# 7   2021-06-27T20:11:08Z        10                    1.0
# 8   2021-06-27T20:11:02Z        10                    1.0
# 9   2021-06-27T22:03:26Z       121                  214.0
# 10  2021-06-28T12:51:29Z        10                    1.0
# 11  2021-06-27T22:01:22Z        10                    5.0
# 12  2021-06-28T12:53:23Z       120                  214.0
# 13  2021-06-28T12:51:24Z        10                    1.0
# 14  2021-06-27T22:01:31Z        10                    1.0
# 15  2021-06-28T13:05:00Z       195                  365.0
# 16  2021-06-27T20:14:01Z        10                    2.0
# 17  2021-06-27T20:14:05Z        10                    5.0
# 18  2021-06-28T13:01:51Z        10                    1.0
# 19  2021-06-28T13:01:47Z        11                    3.0
# 20  2021-06-27T20:17:19Z       195                  366.0
# 21  2021-06-28T12:49:05Z        10                    1.0
# 22  2021-06-27T20:07:00Z        10                    1.0
# 23  2021-06-27T20:06:52Z        10                    5.0
# 24  2021-06-28T12:49:10Z        10                    1.0
# 25  2021-06-27T20:04:41Z       128                  232.0
# 26  2021-06-27T20:09:04Z       129                  231.0
# 27  2021-06-27T20:02:35Z        10                    5.0
# 28  2021-06-28T12:51:09Z       123                  223.0
# 29  2021-06-27T20:02:30Z        10                    2.0
# 30  2021-06-27T22:03:40Z        10                    5.0
# 31  2021-06-28T12:53:37Z        10                    2.0
# 32  2021-06-28T12:53:40Z        10                    1.0
# 33  2021-06-28T12:55:50Z       135                  246.0
# 34  2021-06-27T22:06:08Z       137                  249.0
# 35  2021-06-27T22:03:50Z        10                    5.0
#
#     resourcesDuration_memory
# 0                        6.0
# 1                      132.0
# 2                        1.0
# 3                        2.0
# 4                      298.0
# 5                        1.0
# 6                      293.0
# 7                        1.0
# 8                        1.0
# 9                      214.0
# 10                       1.0
# 11                       5.0
# 12                     214.0
# 13                       1.0
# 14                       1.0
# 15                     365.0
# 16                       2.0
# 17                       5.0
# 18                       1.0
# 19                       3.0
# 20                     366.0
# 21                       1.0
# 22                       1.0
# 23                       5.0
# 24                       1.0
# 25                     232.0
# 26                     231.0
# 27                       5.0
# 28                     223.0
# 29                       2.0
# 30                       5.0
# 31                       2.0
# 32                       1.0
# 33                     246.0
# 34                     249.0
# 35                       5.0

# %%
path = 'results/results.csv'
df_cost = pd.read_csv(path)
df_cost
# Out:
#                         experiment       workflow             startedAt  \
# 0     script_opt_3_overlap_cost_50  sqlflow-wq225  2021-06-29T14:38:23Z
# 1     script_opt_3_overlap_cost_50  sqlflow-rtvh9  2021-06-29T14:36:18Z
# 2     script_opt_3_overlap_cost_50  sqlflow-fxkwz  2021-06-29T14:36:12Z
# 3     script_opt_3_overlap_cost_50  sqlflow-jh2tl  2021-06-29T14:41:04Z
# 4     script_opt_3_overlap_cost_50  sqlflow-nc8lc  2021-06-29T14:36:26Z
# ..                             ...            ...                   ...
# 562  script_opt_1_overlap_cost_150  sqlflow-ls66s  2021-06-28T16:25:22Z
# 563  script_opt_1_overlap_cost_150  sqlflow-hh6ld  2021-06-28T16:25:34Z
# 564  script_opt_1_overlap_cost_150  sqlflow-ck7c5  2021-06-28T16:25:29Z
# 565  script_opt_1_overlap_cost_150  sqlflow-5647z  2021-06-28T16:36:26Z
# 566  script_opt_1_overlap_cost_150  sqlflow-gtvkx  2021-06-28T16:31:04Z
#
#                finishedAt  duration  resourcesDuration_cpu  \
# 0    2021-06-29T14:41:11Z       168                  308.0
# 1    2021-06-29T14:36:28Z        10                    5.0
# 2    2021-06-29T14:36:22Z        10                    2.0
# 3    2021-06-29T14:41:37Z        33                   44.0
# 4    2021-06-29T14:38:31Z       125                  223.0
# ..                    ...       ...                    ...
# 562  2021-06-28T16:25:32Z        10                    2.0
# 563  2021-06-28T16:31:10Z       336                  650.0
# 564  2021-06-28T16:25:39Z        10                    2.0
# 565  2021-06-28T16:36:58Z        32                   42.0
# 566  2021-06-28T16:36:30Z       326                  628.0
#
#      resourcesDuration_memory
# 0                       308.0
# 1                         5.0
# 2                         2.0
# 3                        44.0
# 4                       223.0
# ..                        ...
# 562                       2.0
# 563                     650.0
# 564                       2.0
# 565                      42.0
# 566                     628.0
#
# [567 rows x 7 columns]

# %% [markdown]
# ## Retrieve query index that match the queries

# %%
folder = 'tables/'
for file in glob.glob(folder+"*"):
    print(file)
    df = pd.read_csv(file)
    print(df.shape)
# Out:
# tables/opt_1_overlap_cost_150.csv
# (5000, 82)
# tables/opt_6_overlap_cost_100.csv
# (5000, 82)
# tables/opt_4_overlap_cost_150.csv
# (5000, 82)
# tables/opt_3_order_cost_100.csv
# (5000, 82)
# tables/opt_3_overlap_cost_100.csv
# (5000, 82)
# tables/opt_7_order_cost_150.csv
# (5000, 82)
# tables/base_5_overlap_cost_100.csv
# (5000, 82)
# tables/base_2_overlap_cost_150.csv
# (5000, 82)
# tables/base_0_overlap_cost_100.csv
# (5000, 82)
# tables/base_7_overlap_cost_150.csv
# (5000, 82)
# tables/opt_0_order_cost_100.csv
# (5000, 82)
# tables/base_8_overlap_cost_150.csv
# (5000, 82)
# tables/opt_4_order_cost_150.csv
# (5000, 82)
# tables/base_10_overlap_cost_150.csv
# (5000, 82)
# tables/opt_2_order_cost_150.csv
# (5000, 82)
# tables/opt_2_overlap_cost_50.csv
# (5000, 82)
# tables/opt_6_order_cost_100.csv
# (5000, 82)
# tables/opt_3_overlap_cost_50.csv
# (5000, 82)
# tables/opt_7_overlap_cost_100.csv
# (5000, 82)
# tables/opt_0_overlap_cost_150.csv
# (5000, 82)
# tables/opt_0_overlap_cost_50.csv
# (5000, 82)
# tables/opt_2_overlap_cost_100.csv
# (5000, 82)
# tables/opt_5_overlap_cost_150.csv
# (5000, 82)
# tables/opt_1_overlap_cost_50.csv
# (5000, 82)
# tables/base_9_overlap_cost_150.csv
# (5000, 82)
# tables/opt_5_overlap_cost_50.csv
# (5000, 82)
# tables/base_3_overlap_cost_150.csv
# (5000, 82)
# tables/base_4_overlap_cost_100.csv
# (5000, 82)
# tables/base_6_overlap_cost_150.csv
# (5000, 82)
# tables/opt_4_overlap_cost_50.csv
# (5000, 82)
# tables/opt_1_order_cost_150.csv
# (5000, 82)
# tables/opt_8_order_cost_100.csv
# (5000, 82)
# tables/base_1_overlap_cost_100.csv
# (5000, 82)
# tables/base_5_overlap_cost_150.csv
# (5000, 82)
# tables/base_2_overlap_cost_100.csv
# (5000, 82)
# tables/base_0_overlap_cost_150.csv
# (5000, 82)
# tables/base_7_overlap_cost_100.csv
# (5000, 82)
# tables/opt_0_order_cost_150.csv
# (5000, 82)
# tables/base_8_overlap_cost_100.csv
# (5000, 82)
# tables/opt_3_order_cost_50.csv
# (5000, 82)
# tables/opt_4_order_cost_100.csv
# (5000, 82)
# tables/base_10_overlap_cost_100.csv
# (5000, 82)
# tables/opt_1_overlap_cost_100.csv
# (5000, 82)
# tables/opt_6_overlap_cost_150.csv
# (5000, 82)
# tables/opt_4_overlap_cost_100.csv
# (5000, 82)
# tables/opt_3_order_cost_150.csv
# (5000, 82)
# tables/opt_3_overlap_cost_150.csv
# (5000, 82)
# tables/opt_7_order_cost_100.csv
# (5000, 82)
# tables/yolov5x6.csv
# (5000, 82)
# tables/opt_2_order_cost_50.csv
# (5000, 82)
# tables/yolov3.csv
# (5000, 82)
# tables/yolov5m6.csv
# (5000, 82)
# tables/opt_4_order_cost_50.csv
# (5000, 82)
# tables/base_9_overlap_cost_100.csv
# (5000, 82)
# tables/yolov5m.csv
# (5000, 82)
# tables/yolov5x.csv
# (5000, 82)
# tables/base_3_overlap_cost_100.csv
# (5000, 82)
# tables/base_4_overlap_cost_50.csv
# (5000, 82)
# tables/base_4_overlap_cost_150.csv
# (5000, 82)
# tables/opt_1_order_cost_50.csv
# (5000, 82)
# tables/opt_1_order_cost_100.csv
# (5000, 82)
# tables/base_6_overlap_cost_100.csv
# (5000, 82)
# tables/opt_8_order_cost_150.csv
# (5000, 82)
# tables/base_1_overlap_cost_150.csv
# (5000, 82)
# tables/opt_5_order_cost_150.csv
# (5000, 82)
# tables/opt_2_order_cost_100.csv
# (5000, 82)
# tables/opt_6_order_cost_150.csv
# (5000, 82)
# tables/base_3_overlap_cost_50.csv
# (5000, 82)
# tables/base_2_overlap_cost_50.csv
# (5000, 82)
# tables/base_1_overlap_cost_50.csv
# (5000, 82)
# tables/opt_7_overlap_cost_150.csv
# (5000, 82)
# tables/opt_0_overlap_cost_100.csv
# (5000, 82)
# tables/opt_0_order_cost_50.csv
# (5000, 82)
# tables/opt_2_overlap_cost_150.csv
# (5000, 82)
# tables/base_0_overlap_cost_50.csv
# (5000, 82)
# tables/opt_5_overlap_cost_100.csv
# (5000, 82)

# %%
constraint = 'cost'

path = 'output/coco/summary_'+constraint+'_optimizer.csv'
df_opt = pd.read_csv(path,index_col=0)

path = 'output/coco/summary_order_'+constraint+'_optimizer.csv'
df_order_opt = pd.read_csv(path,index_col=0)

path = 'output/coco/summary_'+constraint+'_baseline_pareto.csv'
df_baseline = pd.read_csv(path,index_col=0)
df_opt
# Out:
#     query_index  qgetSelectivityuery  #predicate    mdist    qdist constraint  \
# 0             1                  NaN           2  uniform  uniform       cost
# 1             1                  NaN           2  uniform  uniform       cost
# 2             1                  NaN           2  uniform  uniform       cost
# 3             0                  NaN           4  uniform  uniform       cost
# 4             0                  NaN           4  uniform  uniform       cost
# 5             0                  NaN           4  uniform  uniform       cost
# 6             7                  NaN           4  uniform  uniform       cost
# 7             7                  NaN           4  uniform  uniform       cost
# 8             6                  NaN           4  uniform  uniform       cost
# 9             6                  NaN           4  uniform  uniform       cost
# 10            6                  NaN           4  uniform  uniform       cost
# 11            6                  NaN           4  uniform  uniform       cost
# 12            2                  NaN           4  uniform  uniform       cost
# 13            2                  NaN           4  uniform  uniform       cost
# 14            2                  NaN           4  uniform  uniform       cost
# 15            4                  NaN           4  uniform  uniform       cost
# 16            4                  NaN           4  uniform  uniform       cost
# 17            4                  NaN           4  uniform  uniform       cost
# 18            3                  NaN           4  uniform  uniform       cost
# 19            3                  NaN           4  uniform  uniform       cost
# 20            3                  NaN           4  uniform  uniform       cost
# 21            9                  NaN           4  uniform  uniform       cost
# 22            9                  NaN           4  uniform  uniform       cost
# 23            8                  NaN           8  uniform  uniform       cost
# 24            8                  NaN           8  uniform  uniform       cost
# 25           10                  NaN           8  uniform  uniform       cost
# 26           10                  NaN           8  uniform  uniform       cost
# 27            5                  NaN           8  uniform  uniform       cost
# 28            5                  NaN           8  uniform  uniform       cost
# 29            5                  NaN           8  uniform  uniform       cost
#
#     bound   approach                                     selected_model  \
# 0   150.0  optimizer                      person.model_41|book.model_82
# 1   100.0  optimizer                     person.model_41|book.model_138
# 2    50.0  optimizer                      person.model_69|book.model_69
# 3   150.0  optimizer  wine_glass.model_41|refrigerator.model_108|ski...
# 4   100.0  optimizer  skis.model_38|wine_glass.model_38|refrigerator...
# 5    50.0  optimizer  wine_glass.model_38|baseball_bat.model_38|skis...
# 6   150.0  optimizer  bird.model_133|traffic_light.model_38|book.mod...
# 7   100.0  optimizer  book.model_133|bowl.model_133|bird.model_133|t...
# 8   100.0  optimizer  bus.model_41|person.model_41|cell_phone.model_...
# 9   150.0  optimizer  bus.model_41|person.model_41|cell_phone.model_...
# 10  100.0  optimizer  cell_phone.model_41|bus.model_41|person.model_...
# 11   50.0  optimizer  person.model_44|bus.model_30|cell_phone.model_...
# 12  150.0  optimizer  bird.model_133|cup.model_90|person.model_141|r...
# 13  100.0  optimizer  remote.model_126|cup.model_90|bird.model_90|pe...
# 14   50.0  optimizer  person.model_44|remote.model_44|bird.model_30|...
# 15  150.0  optimizer  dining_table.model_86|handbag.model_86|person....
# 16  100.0  optimizer  dining_table.model_88|handbag.model_88|clock.m...
# 17   50.0  optimizer  clock.model_44|person.model_44|dining_table.mo...
# 18  150.0  optimizer  train.model_141|person.model_141|bicycle.model...
# 19  100.0  optimizer  bicycle.model_133|handbag.model_133|train.mode...
# 20   50.0  optimizer  bicycle.model_44|handbag.model_44|person.model...
# 21  150.0  optimizer  spoon.model_30|bowl.model_89|tennis_racket.mod...
# 22  100.0  optimizer  bowl.model_130|tennis_racket.model_30|spoon.mo...
# 23  150.0  optimizer  bottle.model_133|dining_table.model_133|car.mo...
# 24  100.0  optimizer  dining_table.model_140|bowl.model_140|bench.mo...
# 25  150.0  optimizer  boat.model_133|frisbee.model_133|truck.model_3...
# 26  100.0  optimizer  bottle.model_133|book.model_133|boat.model_133...
# 27  150.0  optimizer  clock.model_45|chair.model_45|bus.model_41|han...
# 28  100.0  optimizer  clock.model_32|chair.model_32|truck.model_41|s...
# 29   50.0  optimizer  chair.model_32|sink.model_32|person.model_32|b...
#
#                                          pareto_model  #pareto  \
# 0                       person.model_41|book.model_82        2
# 1                      person.model_41|book.model_138        2
# 2                                                 NaN        0
# 3   wine_glass.model_41|refrigerator.model_108|ski...        3
# 4   wine_glass.model_38|refrigerator.model_44|base...        3
# 5   wine_glass.model_38|skis.model_44|refrigerator...        3
# 6               bird.model_133|traffic_light.model_38        2
# 7   bowl.model_133|bird.model_133|traffic_light.mo...        3
# 8   person.model_41|cell_phone.model_41|bottle.mod...        3
# 9   person.model_41|cell_phone.model_41|bottle.mod...        3
# 10  cell_phone.model_41|person.model_41|bottle.mod...        3
# 11  person.model_44|bus.model_30|cell_phone.model_...        4
# 12       bird.model_133|cup.model_90|remote.model_141        3
# 13        remote.model_126|cup.model_90|bird.model_90        3
# 14       person.model_44|remote.model_44|cup.model_30        3
# 15                     person.model_41|clock.model_44        2
# 16                     clock.model_44|person.model_44        2
# 17  clock.model_44|person.model_44|dining_table.mo...        4
# 18  train.model_141|bicycle.model_78|handbag.model_78        3
# 19  bicycle.model_133|train.model_140|person.model_44        3
# 20  bicycle.model_44|handbag.model_44|person.model...        4
# 21  spoon.model_30|bowl.model_89|tennis_racket.mod...        4
# 22  bowl.model_130|tennis_racket.model_30|spoon.mo...        4
# 23  dining_table.model_133|car.model_133|bowl.mode...        7
# 24  dining_table.model_140|bowl.model_140|bench.mo...        6
# 25  boat.model_133|frisbee.model_133|truck.model_3...        7
# 26  boat.model_133|frisbee.model_133|umbrella.mode...        5
# 27  chair.model_45|person.model_41|sink.model_41|t...        4
# 28  chair.model_32|sink.model_41|person.model_41|t...        4
# 29  chair.model_32|sink.model_32|bus.model_30|tenn...        6
#
#                                      non_pareto_model  #non_pareto  \
# 0                                                 NaN            0
# 1                                                 NaN            0
# 2                       person.model_69|book.model_69            2
# 3                               baseball_bat.model_66            1
# 4                                       skis.model_38            1
# 5                               baseball_bat.model_38            1
# 6                         book.model_78|bowl.model_78            2
# 7                                      book.model_133            1
# 8                                        bus.model_41            1
# 9                                        bus.model_41            1
# 10                                       bus.model_41            1
# 11                                                NaN            0
# 12                                   person.model_141            1
# 13                                    person.model_90            1
# 14                                      bird.model_30            1
# 15             dining_table.model_86|handbag.model_86            2
# 16             dining_table.model_88|handbag.model_88            2
# 17                                                NaN            0
# 18                                   person.model_141            1
# 19                                  handbag.model_133            1
# 20                                                NaN            0
# 21                                                NaN            0
# 22                                                NaN            0
# 23                                   bottle.model_133            1
# 24                       couch.model_140|car.model_90            2
# 25                                  umbrella.model_82            1
# 26     bottle.model_133|book.model_133|fork.model_133            3
# 27  clock.model_45|bus.model_41|handbag.model_41|t...            4
# 28  clock.model_32|truck.model_41|bus.model_41|han...            4
# 29                     person.model_32|clock.model_30            2
#
#     pareto_ratio  accuracy        cost  optimization_time  data_process_time  \
# 0          1.000  0.876100  110.000000             0.0179             0.0027
# 1          1.000  0.874000   87.000000             0.0194             0.0022
# 2          0.000  0.841400   39.000000             0.0184             0.0021
# 3          0.750  0.761319  136.999958             0.0499             0.1151
# 4          0.750  0.746044   93.000000             0.0586             0.1163
# 5          0.750  0.729927   50.000000             0.0359             0.1166
# 6          0.500  0.884160  140.000000             0.0534             0.0022
# 7          0.750  0.880460   71.000000             0.0482             0.0020
# 8          0.750  0.941157   82.000000             0.0517             0.0018
# 9          0.750  0.944174  118.000000             0.0421             0.1918
# 10         0.750  0.941157   82.000000             0.0515             0.1166
# 11         1.000  0.931303   47.000000             0.0333             0.0019
# 12         0.750  0.687271  147.000000             0.0318             0.0019
# 13         0.750  0.672064   91.000000             0.0468             0.0022
# 14         0.750  0.628628   47.000000             0.0257             0.0025
# 15         0.500  0.899098  150.000000             0.0433             0.0019
# 16         0.500  0.890938   90.000000             0.0482             0.0019
# 17         1.000  0.860935   47.000000             0.0349             0.0026
# 18         0.750  0.752861  129.000000             0.0379             0.0024
# 19         0.750  0.710052   96.000000             0.0783             0.0020
# 20         1.000  0.634699   49.000000             0.0305             0.0025
# 21         1.000  0.957931  149.000000             0.0449             0.0018
# 22         1.000  0.949695   99.000000             0.0538             0.0018
# 23         0.875  0.787998  147.000000             0.1110             0.0021
# 24         0.750  0.780759   96.000000             0.1267             0.0019
# 25         0.875  0.912217  129.000000             0.1017             0.0020
# 26         0.625  0.908921   97.000000             0.0962             0.0021
# 27         0.500  0.998147  135.000000             0.1108             0.0023
# 28         0.500  0.997961   99.000000             0.1168             0.0019
# 29         0.750  0.995914   50.000000             0.0621             0.0024
#
#                                                 query
# 0                                       book | person
# 1                                       book | person
# 2                                       book | person
# 3   (baseball_bat & skis & refrigerator) | wine_glass
# 4   (baseball_bat & skis & refrigerator) | wine_glass
# 5   (baseball_bat & skis & refrigerator) | wine_glass
# 6                (book & bird) | traffic_light | bowl
# 7                (book & bird) | traffic_light | bowl
# 8                  bus & person | cell_phone | bottle
# 9                  bus & person | cell_phone | bottle
# 10                 bus & person | cell_phone | bottle
# 11                 bus & person | cell_phone | bottle
# 12                       cup & person & remote | bird
# 13                       cup & person & remote | bird
# 14                       cup & person & remote | bird
# 15            dining_table | person & clock | handbag
# 16            dining_table | person & clock | handbag
# 17            dining_table | person & clock | handbag
# 18                 handbag & person | train & bicycle
# 19                 handbag & person | train & bicycle
# 20                 handbag & person | train & bicycle
# 21               tennis_racket | (spoon & bowl) | tie
# 22               tennis_racket | (spoon & bowl) | tie
# 23  (bottle & dining_table) | (bowl & couch & car ...
# 24  (bottle & dining_table) | (bowl & couch & car ...
# 25  (truck & fork & umbrella & book) | (boat & fri...
# 26  (truck & fork & umbrella & book) | (boat & fri...
# 27  bus | person | handbag & truck & clock & chair...
# 28  bus | person | handbag & truck & clock & chair...
# 29  bus | person | handbag & truck & clock & chair...

# %% [markdown]
# ## Model repository

# %%
df_model = pd.read_csv('repository/model_stats_f1.csv',index_col=0)
df_model
# Out:
#            snowboard  carrot  keyboard  cell phone  sports ball  clock   bus  \
# model_64        0.31    0.44      0.45        0.43         0.50   0.53  0.57
# model_45        0.39    0.41       NaN         NaN          NaN   0.61  0.60
# model_133        NaN     NaN      0.68         NaN         0.74    NaN   NaN
# model_132       0.46    0.40       NaN         NaN          NaN   0.66  0.74
# model_32         NaN    0.46       NaN         NaN          NaN   0.68   NaN
# ...              ...     ...       ...         ...          ...    ...   ...
# model_146        NaN     NaN       NaN         NaN         0.65    NaN   NaN
# model_135        NaN    0.46       NaN        0.52          NaN   0.73   NaN
# model_76         NaN    0.47       NaN         NaN          NaN    NaN   NaN
# model_26         NaN     NaN       NaN         NaN          NaN    NaN   NaN
# model_47         NaN     NaN       NaN         NaN          NaN    NaN   NaN
#
#            person  surfboard  refrigerator  ...  tennis racket  toaster  \
# model_64     0.68       0.53          0.50  ...            NaN      NaN
# model_45      NaN        NaN           NaN  ...            NaN      NaN
# model_133     NaN       0.73          0.63  ...            NaN      NaN
# model_132    0.73       0.67           NaN  ...            0.7     0.24
# model_32     0.73       0.64           NaN  ...            NaN     0.18
# ...           ...        ...           ...  ...            ...      ...
# model_146     NaN        NaN          0.42  ...            NaN      NaN
# model_135     NaN        NaN          0.54  ...            NaN     0.36
# model_76     0.75        NaN           NaN  ...            NaN      NaN
# model_26      NaN        NaN           NaN  ...            NaN      NaN
# model_47      NaN        NaN           NaN  ...            NaN      NaN
#
#            zebra  fire hydrant  motorcycle   cat  potted plant  wine glass  \
# model_64     NaN           NaN         NaN   NaN           NaN         NaN
# model_45     NaN           NaN         NaN   NaN           NaN         NaN
# model_133    NaN           NaN         NaN   NaN           NaN         NaN
# model_132   0.74           NaN         NaN   NaN           NaN         NaN
# model_32    0.78          0.63        0.69  0.77          0.58         NaN
# ...          ...           ...         ...   ...           ...         ...
# model_146    NaN           NaN         NaN   NaN           NaN         NaN
# model_135   0.82          0.63        0.73   NaN          0.61         NaN
# model_76     NaN           NaN         NaN   NaN          0.63        0.59
# model_26     NaN           NaN         NaN   NaN           NaN         NaN
# model_47     NaN          0.85         NaN   NaN           NaN         NaN
#
#            baseball bat  truck
# model_64            NaN    NaN
# model_45            NaN    NaN
# model_133           NaN    NaN
# model_132           NaN    NaN
# model_32            NaN    NaN
# ...                 ...    ...
# model_146           NaN    NaN
# model_135          0.61   0.44
# model_76            NaN    NaN
# model_26            NaN   0.47
# model_47            NaN   0.48
#
# [125 rows x 81 columns]

# %%
bound = 150
for idx in range(10):
    print('query '+str(idx))
    subset = df_opt[(df_opt.query_index==idx)]
    print(subset['query'].values[0])
    selected_model = subset.selected_model.values[0]
    assignment = {item.split('.')[0].replace('_',' '):item.split('.')[1] for item in selected_model.split('|')}
    print(assignment)
    for k,v in assignment.items():
        print(k,v)
        print(df_model.loc[v,k])
    print('==========')
# Out:
# query 0
# (baseball_bat & skis & refrigerator) | wine_glass
# {'wine glass': 'model_41', 'refrigerator': 'model_108', 'skis': 'model_66', 'baseball bat': 'model_66'}
# wine glass model_41
# 0.64
# refrigerator model_108
# 0.67
# skis model_66
# 0.74
# baseball bat model_66
# 0.69
# ==========
# query 1
# book | person
# {'person': 'model_41', 'book': 'model_82'}
# person model_41
# 0.79
# book model_82
# 0.41
# ==========
# query 2
# cup & person & remote | bird
# {'bird': 'model_133', 'cup': 'model_90', 'person': 'model_141', 'remote': 'model_141'}
# bird model_133
# 0.53
# cup model_90
# 0.66
# person model_141
# 0.78
# remote model_141
# 0.65
# ==========
# query 3
# handbag & person | train & bicycle
# {'train': 'model_141', 'person': 'model_141', 'bicycle': 'model_78', 'handbag': 'model_78'}
# train model_141
# 0.86
# person model_141
# 0.78
# bicycle model_78
# 0.72
# handbag model_78
# 0.45
# ==========
# query 4
# dining_table | person & clock | handbag
# {'dining table': 'model_86', 'handbag': 'model_86', 'person': 'model_41', 'clock': 'model_44'}
# dining table model_86
# 0.54
# handbag model_86
# 0.44
# person model_41
# 0.79
# clock model_44
# 0.77
# ==========
# query 5
# bus | person | handbag & truck & clock & chair | tennis_racket | sink
# {'clock': 'model_45', 'chair': 'model_45', 'bus': 'model_41', 'handbag': 'model_41', 'person': 'model_41', 'truck': 'model_41', 'sink': 'model_41', 'tennis racket': 'model_141'}
# clock model_45
# 0.61
# chair model_45
# 0.5
# bus model_41
# 0.8
# handbag model_41
# 0.39
# person model_41
# 0.79
# truck model_41
# 0.48
# sink model_41
# 0.74
# tennis racket model_141
# 0.82
# ==========
# query 6
# bus & person | cell_phone | bottle
# {'bus': 'model_41', 'person': 'model_41', 'cell phone': 'model_41', 'bottle': 'model_33'}
# bus model_41
# 0.8
# person model_41
# 0.79
# cell phone model_41
# 0.59
# bottle model_33
# 0.61
# ==========
# query 7
# (book & bird) | traffic_light | bowl
# {'bird': 'model_133', 'traffic light': 'model_38', 'book': 'model_78', 'bowl': 'model_78'}
# bird model_133
# 0.53
# traffic light model_38
# 0.63
# book model_78
# 0.41
# bowl model_78
# 0.6
# ==========
# query 8
# (bottle & dining_table) | (bowl & couch & car & fork & bench) | cup
# {'bottle': 'model_133', 'dining table': 'model_133', 'car': 'model_133', 'bowl': 'model_133', 'couch': 'model_44', 'fork': 'model_90', 'cup': 'model_90', 'bench': 'model_42'}
# bottle model_133
# 0.61
# dining table model_133
# 0.54
# car model_133
# 0.7
# bowl model_133
# 0.59
# couch model_44
# 0.51
# fork model_90
# 0.68
# cup model_90
# 0.66
# bench model_42
# 0.49
# ==========
# query 9
# tennis_racket | (spoon & bowl) | tie
# {'spoon': 'model_30', 'bowl': 'model_89', 'tennis racket': 'model_89', 'tie': 'model_55'}
# spoon model_30
# 0.41
# bowl model_89
# 0.61
# tennis racket model_89
# 0.83
# tie model_55
# 0.67
# ==========

# %% [markdown]
# ## Collect statistics

# %%
import glob
import re
import pandas as pd
from sympy.parsing.sympy_parser import parse_expr

constraint = 'cost'

df_result = pd.DataFrame(columns=['name','query_index','query','constraint','bound',\
                                  'len','accuracy','cost','total_cost','objective_accuracy','objective_cost','result_index'])

# %%
import numpy as np
def getImageIndex(query,df):
    Bxp = parse_expr(query)
    predicates = [str(p) for p in list(Bxp.atoms())]
    print(predicates)
    subset = df[predicates].dropna(how='all')
    subset.replace(0, np.nan, inplace=True)
    subset = pd.notnull(subset)
#     subset[subset != 0] = True
    
    index = [i for i, row in subset.iterrows() if Bxp.subs({p:row[str(p)] for p in list(Bxp.atoms())}) == True ]
    print('len(index)',len(index))
    return index

# %%
path = 'results/results.csv'
df_cost = pd.read_csv(path)
df_cost
# Out:
#                         experiment       workflow             startedAt  \
# 0     script_opt_3_overlap_cost_50  sqlflow-wq225  2021-06-29T14:38:23Z
# 1     script_opt_3_overlap_cost_50  sqlflow-rtvh9  2021-06-29T14:36:18Z
# 2     script_opt_3_overlap_cost_50  sqlflow-fxkwz  2021-06-29T14:36:12Z
# 3     script_opt_3_overlap_cost_50  sqlflow-jh2tl  2021-06-29T14:41:04Z
# 4     script_opt_3_overlap_cost_50  sqlflow-nc8lc  2021-06-29T14:36:26Z
# ..                             ...            ...                   ...
# 613  script_opt_1_overlap_cost_150  sqlflow-ls66s  2021-06-28T16:25:22Z
# 614  script_opt_1_overlap_cost_150  sqlflow-hh6ld  2021-06-28T16:25:34Z
# 615  script_opt_1_overlap_cost_150  sqlflow-ck7c5  2021-06-28T16:25:29Z
# 616  script_opt_1_overlap_cost_150  sqlflow-5647z  2021-06-28T16:36:26Z
# 617  script_opt_1_overlap_cost_150  sqlflow-gtvkx  2021-06-28T16:31:04Z
#
#                finishedAt  duration  resourcesDuration_cpu  \
# 0    2021-06-29T14:41:11Z       168                  308.0
# 1    2021-06-29T14:36:28Z        10                    5.0
# 2    2021-06-29T14:36:22Z        10                    2.0
# 3    2021-06-29T14:41:37Z        33                   44.0
# 4    2021-06-29T14:38:31Z       125                  223.0
# ..                    ...       ...                    ...
# 613  2021-06-28T16:25:32Z        10                    2.0
# 614  2021-06-28T16:31:10Z       336                  650.0
# 615  2021-06-28T16:25:39Z        10                    2.0
# 616  2021-06-28T16:36:58Z        32                   42.0
# 617  2021-06-28T16:36:30Z       326                  628.0
#
#      resourcesDuration_memory
# 0                       308.0
# 1                         5.0
# 2                         2.0
# 3                        44.0
# 4                       223.0
# ..                        ...
# 613                       2.0
# 614                     650.0
# 615                       2.0
# 616                      42.0
# 617                     628.0
#
# [618 rows x 7 columns]

# %%
folder = 'tables/'
for file in glob.glob(folder+"*"):
    print(file)
    df = pd.read_csv(file)
    print(df.shape)
    
    name = file.split('/')[-1].split('.')[0]
    print('name',name)
    if len(name.split('_')) < 4:
        continue

    if not df_result[df_result['name'] == name].empty:
        continue
    
    # retrieve cost
    total_cost = df_cost[(df_cost['experiment']=='script_'+name) & (df_cost['duration']>10)]['duration'].sum()/5
#     cost = df_cost[(df_cost['experiment']=='script_'+name)]['duration'][::-2].sum()-10
    subset = df_cost[(df_cost['experiment']=='script_'+name)]
    s = list(subset.sort_values(by=['startedAt'])['duration'][2:]) # [2,3,::2]
    print(s)
    try:
        cost = sum([s[0]]+s[1:][::2]) / 5
    except:
        cost = total_cost
    print('cost',cost)

    order = name.split('_')[2] == 'order'
    print('order',order)
    
    query_idx = int(re.search(r'\d+', name).group(0))
    print(query_idx)
    
    consr_type = re.search(r'.*_([a-z]+)_.*', name).group(1)
    if consr_type != constraint:
        continue
        
    bound = re.search(r'.*_(\d+)', name).group(1)
    query = queryList[query_idx]
    
    if order:
        df_record = df_order_opt
        approach = 'order_opt'
    elif name[:3] == 'opt':
        df_record = df_opt
        approach = 'basic_opt'
    else:
        df_record = df_baseline
        approach = 'baseline'
        
    # Match objective value with extracted accuracy results
    record = df_record[(df_record['query_index']==query_idx) & (df_record['constraint']==consr_type) \
                       & (df_record['bound']==int(bound))]
#     print(record)
    
    index = getImageIndex(query,df)
    gt = list(filter(lambda x: x>=2000, indexList[query_idx]))
    label = list(filter(lambda x: x>=2000,index))
    intersection = list(set.intersection(set(gt), set(label)))
    
    print('intersect',len(intersection))
    print('total',len(gt))
    
    accu = len(intersection)/len(gt)
    print('accu',accu)
    result_idx = ','.join([str(i) for i in index])

    new_row = pd.DataFrame([{'name':name,'query_index':query_idx,'query':query,\
                             'constraint':constraint,'bound':bound,'approach':approach,'len':len(index),\
                             'accuracy':round(accu,4),'cost':cost,'total_cost':total_cost,'objective_accuracy':round(record.accuracy.values[0],4),\
                             'objective_cost':int(record['cost'].values[0]),'result_index':result_idx}])
#     print(new_row)
    df_result = df_result.append(new_row, ignore_index=True)
    
    print('----------')
    print()
# Out:
# tables/opt_1_overlap_cost_150.csv
# (5000, 82)
# name opt_1_overlap_cost_150
# tables/opt_6_overlap_cost_100.csv
# (5000, 82)
# name opt_6_overlap_cost_100
# tables/opt_4_overlap_cost_150.csv
# (5000, 82)
# name opt_4_overlap_cost_150
# tables/opt_3_order_cost_100.csv
# (5000, 82)
# name opt_3_order_cost_100
# tables/opt_3_overlap_cost_100.csv
# (5000, 82)
# name opt_3_overlap_cost_100
# tables/opt_7_order_cost_150.csv
# (5000, 82)
# name opt_7_order_cost_150
# tables/opt_9_overlap_cost_100.csv
# (5000, 82)
# name opt_9_overlap_cost_100
# tables/base_5_overlap_cost_100.csv
# (5000, 82)
# name base_5_overlap_cost_100
# tables/base_2_overlap_cost_150.csv
# (5000, 82)
# name base_2_overlap_cost_150
# tables/base_0_overlap_cost_100.csv
# (5000, 82)
# name base_0_overlap_cost_100
# tables/base_7_overlap_cost_150.csv
# (5000, 82)
# name base_7_overlap_cost_150
# tables/opt_0_order_cost_100.csv
# (5000, 82)
# name opt_0_order_cost_100
# tables/base_8_overlap_cost_150.csv
# (5000, 82)
# name base_8_overlap_cost_150
# tables/opt_9_order_cost_150.csv
# (5000, 82)
# name opt_9_order_cost_150
# tables/opt_4_order_cost_150.csv
# (5000, 82)
# name opt_4_order_cost_150
# tables/base_10_overlap_cost_150.csv
# (5000, 82)
# name base_10_overlap_cost_150
# tables/opt_2_order_cost_150.csv
# (5000, 82)
# name opt_2_order_cost_150
# tables/opt_2_overlap_cost_50.csv
# (5000, 82)
# name opt_2_overlap_cost_50
# tables/opt_6_order_cost_100.csv
# (5000, 82)
# name opt_6_order_cost_100
# tables/opt_3_overlap_cost_50.csv
# (5000, 82)
# name opt_3_overlap_cost_50
# tables/opt_8_overlap_cost_100.csv
# (5000, 82)
# name opt_8_overlap_cost_100
# tables/opt_7_overlap_cost_100.csv
# (5000, 82)
# name opt_7_overlap_cost_100
# tables/opt_0_overlap_cost_150.csv
# (5000, 82)
# name opt_0_overlap_cost_150
# tables/opt_0_overlap_cost_50.csv
# (5000, 82)
# name opt_0_overlap_cost_50
# tables/opt_2_overlap_cost_100.csv
# (5000, 82)
# name opt_2_overlap_cost_100
# tables/opt_5_overlap_cost_150.csv
# (5000, 82)
# name opt_5_overlap_cost_150
# tables/opt_1_overlap_cost_50.csv
# (5000, 82)
# name opt_1_overlap_cost_50
# tables/base_9_overlap_cost_150.csv
# (5000, 82)
# name base_9_overlap_cost_150
# tables/opt_10_overlap_cost_150.csv
# (5000, 82)
# name opt_10_overlap_cost_150
# [253, 167, 34, 338, 34]
# cost 151.6
# order False
# 10
# ['apple', 'umbrella', 'truck', 'fork', 'frisbee', 'boat', 'bottle', 'book']
# len(index) 563
# intersect 211
# total 261
# accu 0.8084291187739464
# ----------
#
# tables/opt_5_overlap_cost_50.csv
# (5000, 82)
# name opt_5_overlap_cost_50
# tables/base_3_overlap_cost_150.csv
# (5000, 82)
# name base_3_overlap_cost_150
# tables/base_4_overlap_cost_100.csv
# (5000, 82)
# name base_4_overlap_cost_100
# tables/base_6_overlap_cost_150.csv
# (5000, 82)
# name base_6_overlap_cost_150
# tables/opt_4_overlap_cost_50.csv
# (5000, 82)
# name opt_4_overlap_cost_50
# tables/opt_1_order_cost_150.csv
# (5000, 82)
# name opt_1_order_cost_150
# tables/opt_8_order_cost_100.csv
# (5000, 82)
# name opt_8_order_cost_100
# tables/base_1_overlap_cost_100.csv
# (5000, 82)
# name base_1_overlap_cost_100
# tables/base_5_overlap_cost_150.csv
# (5000, 82)
# name base_5_overlap_cost_150
# tables/base_2_overlap_cost_100.csv
# (5000, 82)
# name base_2_overlap_cost_100
# tables/base_0_overlap_cost_150.csv
# (5000, 82)
# name base_0_overlap_cost_150
# tables/base_7_overlap_cost_100.csv
# (5000, 82)
# name base_7_overlap_cost_100
# tables/opt_0_order_cost_150.csv
# (5000, 82)
# name opt_0_order_cost_150
# tables/base_8_overlap_cost_100.csv
# (5000, 82)
# name base_8_overlap_cost_100
# tables/opt_9_order_cost_100.csv
# (5000, 82)
# name opt_9_order_cost_100
# tables/opt_3_order_cost_50.csv
# (5000, 82)
# name opt_3_order_cost_50
# tables/opt_4_order_cost_100.csv
# (5000, 82)
# name opt_4_order_cost_100
# tables/base_10_overlap_cost_100.csv
# (5000, 82)
# name base_10_overlap_cost_100
# tables/opt_1_overlap_cost_100.csv
# (5000, 82)
# name opt_1_overlap_cost_100
# tables/opt_6_overlap_cost_150.csv
# (5000, 82)
# name opt_6_overlap_cost_150
# tables/opt_4_overlap_cost_100.csv
# (5000, 82)
# name opt_4_overlap_cost_100
# tables/opt_3_order_cost_150.csv
# (5000, 82)
# name opt_3_order_cost_150
# tables/opt_3_overlap_cost_150.csv
# (5000, 82)
# name opt_3_overlap_cost_150
# tables/opt_7_order_cost_100.csv
# (5000, 82)
# name opt_7_order_cost_100
# tables/yolov5x6.csv
# (5000, 82)
# name yolov5x6
# tables/opt_2_order_cost_50.csv
# (5000, 82)
# name opt_2_order_cost_50
# tables/yolov3.csv
# (5000, 82)
# name yolov3
# tables/yolov5m6.csv
# (5000, 82)
# name yolov5m6
# tables/opt_9_overlap_cost_150.csv
# (5000, 82)
# name opt_9_overlap_cost_150
# tables/opt_4_order_cost_50.csv
# (5000, 82)
# name opt_4_order_cost_50
# tables/base_9_overlap_cost_100.csv
# (5000, 82)
# name base_9_overlap_cost_100
# tables/yolov5m.csv
# (5000, 82)
# name yolov5m
# tables/yolov5x.csv
# (5000, 82)
# name yolov5x
# tables/base_3_overlap_cost_100.csv
# (5000, 82)
# name base_3_overlap_cost_100
# tables/base_4_overlap_cost_50.csv
# (5000, 82)
# name base_4_overlap_cost_50
# tables/base_4_overlap_cost_150.csv
# (5000, 82)
# name base_4_overlap_cost_150
# tables/opt_1_order_cost_50.csv
# (5000, 82)
# name opt_1_order_cost_50
# tables/opt_1_order_cost_100.csv
# (5000, 82)
# name opt_1_order_cost_100
# tables/base_6_overlap_cost_100.csv
# (5000, 82)
# name base_6_overlap_cost_100
# tables/opt_8_order_cost_150.csv
# (5000, 82)
# name opt_8_order_cost_150
# tables/base_1_overlap_cost_150.csv
# (5000, 82)
# name base_1_overlap_cost_150
# tables/opt_5_order_cost_150.csv
# (5000, 82)
# name opt_5_order_cost_150
# tables/opt_2_order_cost_100.csv
# (5000, 82)
# name opt_2_order_cost_100
# tables/opt_6_order_cost_150.csv
# (5000, 82)
# name opt_6_order_cost_150
# tables/base_3_overlap_cost_50.csv
# (5000, 82)
# name base_3_overlap_cost_50
# tables/opt_8_overlap_cost_150.csv
# (5000, 82)
# name opt_8_overlap_cost_150
# tables/base_2_overlap_cost_50.csv
# (5000, 82)
# name base_2_overlap_cost_50
# tables/base_1_overlap_cost_50.csv
# (5000, 82)
# name base_1_overlap_cost_50
# tables/opt_7_overlap_cost_150.csv
# (5000, 82)
# name opt_7_overlap_cost_150
# tables/opt_0_overlap_cost_100.csv
# (5000, 82)
# name opt_0_overlap_cost_100
# tables/opt_0_order_cost_50.csv
# (5000, 82)
# name opt_0_order_cost_50
# tables/opt_2_overlap_cost_150.csv
# (5000, 82)
# name opt_2_overlap_cost_150
# tables/base_0_overlap_cost_50.csv
# (5000, 82)
# name base_0_overlap_cost_50
# tables/opt_5_overlap_cost_100.csv
# (5000, 82)
# name opt_5_overlap_cost_100

# %%
folder = 'tables/'

# model_cost = {'yolov3':25.6,'yolov5'}

for file in glob.glob(folder+'yolov*.csv'):
    
    df = pd.read_csv(file)

    name = file.split('/')[-1].split('.')[0]
    print('name',name)
    

    # retrieve cost
    cost = df_cost[(df_cost['experiment']=='script_'+name) & (df_cost['duration']>10)]['duration'].sum()
    cost = cost / 5
    print('cost',cost)

    for i in range(10):
        print('idx',i)
        if not df_result[(df_result['name'] == name) & (df_result['query_index']==i)].empty:
            continue
        query = queryList[i]
        index = getImageIndex(query,df)
        gt = list(filter(lambda x: x>=2000, indexList[i]))
        label = list(filter(lambda x: x>=2000,index))
        intersection = list(set.intersection(set(gt), set(label)))
        print('intersect',len(intersection))
        print('total',len(gt))
        accu = len(intersection)/len(gt)
        print('accu',accu)
        result_idx = ','.join([str(i) for i in index])

        new_row = pd.DataFrame([{'name':name,'query_index':i,'query':query,\
                                 'constraint':'cost','bound':bound,'approach':'gt','len':len(index),\
                                 'accuracy':round(accu,4),'cost':cost,'objective_accuracy':1.0,\
                                 'objective_cost':0,'result_index':result_idx}])
    #     print(new_row)
        df_result = df_result.append(new_row, ignore_index=True)

        print('----------')
        print()
# Out:
# name yolov5x6
# cost 0.0
# idx 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 106
# intersect 56
# total 63
# accu 0.8888888888888888
# ----------
#
# idx 1
# ['person', 'book']
# len(index) 2832
# intersect 1632
# total 1692
# accu 0.9645390070921985
# ----------
#
# idx 2
# ['bird', 'person', 'remote', 'cup']
# len(index) 129
# intersect 65
# total 80
# accu 0.8125
# ----------
#
# idx 3
# ['bicycle', 'handbag', 'train', 'person']
# len(index) 242
# intersect 109
# total 180
# accu 0.6055555555555555
# ----------
#
# idx 4
# ['dining_table', 'clock', 'handbag', 'person']
# len(index) 845
# intersect 357
# total 489
# accu 0.7300613496932515
# ----------
#
# idx 5
# ['chair', 'tennis_racket', 'sink', 'truck', 'handbag', 'bus', 'clock', 'person']
# len(index) 2890
# intersect 1680
# total 1741
# accu 0.9649626651349799
# ----------
#
# idx 6
# ['cell_phone', 'bus', 'person', 'bottle']
# len(index) 705
# intersect 324
# total 419
# accu 0.7732696897374701
# ----------
#
# idx 7
# ['bowl', 'traffic_light', 'bird', 'book']
# len(index) 499
# intersect 242
# total 307
# accu 0.7882736156351792
# ----------
#
# idx 8
# ['cup', 'bowl', 'dining_table', 'fork', 'couch', 'bench', 'car', 'bottle']
# len(index) 454
# intersect 212
# total 269
# accu 0.7881040892193308
# ----------
#
# idx 9
# ['tennis_racket', 'bowl', 'spoon', 'tie']
# len(index) 394
# intersect 200
# total 231
# accu 0.8658008658008658
# ----------
#
# name yolov3
# cost 0.0
# idx 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 107
# intersect 56
# total 63
# accu 0.8888888888888888
# ----------
#
# idx 1
# ['person', 'book']
# len(index) 2748
# intersect 1576
# total 1692
# accu 0.9314420803782506
# ----------
#
# idx 2
# ['bird', 'person', 'remote', 'cup']
# len(index) 138
# intersect 62
# total 80
# accu 0.775
# ----------
#
# idx 3
# ['bicycle', 'handbag', 'train', 'person']
# len(index) 210
# intersect 99
# total 180
# accu 0.55
# ----------
#
# idx 4
# ['dining_table', 'clock', 'handbag', 'person']
# len(index) 603
# intersect 267
# total 489
# accu 0.5460122699386503
# ----------
#
# idx 5
# ['chair', 'tennis_racket', 'sink', 'truck', 'handbag', 'bus', 'clock', 'person']
# len(index) 2789
# intersect 1615
# total 1741
# accu 0.9276278001148766
# ----------
#
# idx 6
# ['cell_phone', 'bus', 'person', 'bottle']
# len(index) 715
# intersect 323
# total 419
# accu 0.7708830548926014
# ----------
#
# idx 7
# ['bowl', 'traffic_light', 'bird', 'book']
# len(index) 494
# intersect 231
# total 307
# accu 0.752442996742671
# ----------
#
# idx 8
# ['cup', 'bowl', 'dining_table', 'fork', 'couch', 'bench', 'car', 'bottle']
# len(index) 459
# intersect 204
# total 269
# accu 0.758364312267658
# ----------
#
# idx 9
# ['tennis_racket', 'bowl', 'spoon', 'tie']
# len(index) 358
# intersect 186
# total 231
# accu 0.8051948051948052
# ----------
#
# name yolov5m6
# cost 0.0
# idx 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 108
# intersect 53
# total 63
# accu 0.8412698412698413
# ----------
#
# idx 1
# ['person', 'book']
# len(index) 2813
# intersect 1612
# total 1692
# accu 0.9527186761229315
# ----------
#
# idx 2
# ['bird', 'person', 'remote', 'cup']
# len(index) 132
# intersect 65
# total 80
# accu 0.8125
# ----------
#
# idx 3
# ['bicycle', 'handbag', 'train', 'person']
# len(index) 210
# intersect 101
# total 180
# accu 0.5611111111111111
# ----------
#
# idx 4
# ['dining_table', 'clock', 'handbag', 'person']
# len(index) 816
# intersect 343
# total 489
# accu 0.7014314928425358
# ----------
#
# idx 5
# ['chair', 'tennis_racket', 'sink', 'truck', 'handbag', 'bus', 'clock', 'person']
# len(index) 2864
# intersect 1658
# total 1741
# accu 0.9523262492820218
# ----------
#
# idx 6
# ['cell_phone', 'bus', 'person', 'bottle']
# len(index) 681
# intersect 311
# total 419
# accu 0.7422434367541766
# ----------
#
# idx 7
# ['bowl', 'traffic_light', 'bird', 'book']
# len(index) 495
# intersect 237
# total 307
# accu 0.7719869706840391
# ----------
#
# idx 8
# ['cup', 'bowl', 'dining_table', 'fork', 'couch', 'bench', 'car', 'bottle']
# len(index) 439
# intersect 205
# total 269
# accu 0.7620817843866171
# ----------
#
# idx 9
# ['tennis_racket', 'bowl', 'spoon', 'tie']
# len(index) 355
# intersect 188
# total 231
# accu 0.8138528138528138
# ----------
#
# name yolov5m
# cost 0.0
# idx 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 107
# intersect 56
# total 63
# accu 0.8888888888888888
# ----------
#
# idx 1
# ['person', 'book']
# len(index) 2839
# intersect 1618
# total 1692
# accu 0.9562647754137116
# ----------
#
# idx 2
# ['bird', 'person', 'remote', 'cup']
# len(index) 140
# intersect 65
# total 80
# accu 0.8125
# ----------
#
# idx 3
# ['bicycle', 'handbag', 'train', 'person']
# len(index) 218
# intersect 102
# total 180
# accu 0.5666666666666667
# ----------
#
# idx 4
# ['dining_table', 'clock', 'handbag', 'person']
# len(index) 788
# intersect 327
# total 489
# accu 0.6687116564417178
# ----------
#
# idx 5
# ['chair', 'tennis_racket', 'sink', 'truck', 'handbag', 'bus', 'clock', 'person']
# len(index) 2884
# intersect 1659
# total 1741
# accu 0.9529006318207927
# ----------
#
# idx 6
# ['cell_phone', 'bus', 'person', 'bottle']
# len(index) 726
# intersect 329
# total 419
# accu 0.7852028639618138
# ----------
#
# idx 7
# ['bowl', 'traffic_light', 'bird', 'book']
# len(index) 538
# intersect 247
# total 307
# accu 0.8045602605863192
# ----------
#
# idx 8
# ['cup', 'bowl', 'dining_table', 'fork', 'couch', 'bench', 'car', 'bottle']
# len(index) 473
# intersect 207
# total 269
# accu 0.7695167286245354
# ----------
#
# idx 9
# ['tennis_racket', 'bowl', 'spoon', 'tie']
# len(index) 383
# intersect 192
# total 231
# accu 0.8311688311688312
# ----------
#
# name yolov5x
# cost 0.0
# idx 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 110
# intersect 58
# total 63
# accu 0.9206349206349206
# ----------
#
# idx 1
# ['person', 'book']
# len(index) 2884
# intersect 1648
# total 1692
# accu 0.9739952718676123
# ----------
#
# idx 2
# ['bird', 'person', 'remote', 'cup']
# len(index) 151
# intersect 65
# total 80
# accu 0.8125
# ----------
#
# idx 3
# ['bicycle', 'handbag', 'train', 'person']
# len(index) 281
# intersect 122
# total 180
# accu 0.6777777777777778
# ----------
#
# idx 4
# ['dining_table', 'clock', 'handbag', 'person']
# len(index) 884
# intersect 352
# total 489
# accu 0.7198364008179959
# ----------
#
# idx 5
# ['chair', 'tennis_racket', 'sink', 'truck', 'handbag', 'bus', 'clock', 'person']
# len(index) 2926
# intersect 1686
# total 1741
# accu 0.9684089603676048
# ----------
#
# idx 6
# ['cell_phone', 'bus', 'person', 'bottle']
# len(index) 779
# intersect 346
# total 419
# accu 0.8257756563245824
# ----------
#
# idx 7
# ['bowl', 'traffic_light', 'bird', 'book']
# len(index) 550
# intersect 249
# total 307
# accu 0.8110749185667753
# ----------
#
# idx 8
# ['cup', 'bowl', 'dining_table', 'fork', 'couch', 'bench', 'car', 'bottle']
# len(index) 514
# intersect 219
# total 269
# accu 0.8141263940520446
# ----------
#
# idx 9
# ['tennis_racket', 'bowl', 'spoon', 'tie']
# len(index) 415
# intersect 204
# total 231
# accu 0.8831168831168831
# ----------

# %%
df_result
# Out:
#                        name query_index  \
# 0    opt_1_overlap_cost_150           1
# 1    opt_6_overlap_cost_100           6
# 2    opt_4_overlap_cost_150           4
# 3      opt_3_order_cost_100           3
# 4    opt_3_overlap_cost_100           3
# ..                      ...         ...
# 122                 yolov5x           5
# 123                 yolov5x           6
# 124                 yolov5x           7
# 125                 yolov5x           8
# 126                 yolov5x           9
#
#                                                  query constraint bound   len  \
# 0                                        book | person       cost   150  2882
# 1                   bus & person | cell_phone | bottle       cost   100   711
# 2              dining_table | person & clock | handbag       cost   150   953
# 3                   handbag & person | train & bicycle       cost   100   240
# 4                   handbag & person | train & bicycle       cost   100   276
# ..                                                 ...        ...   ...   ...
# 122  bus | person | handbag & truck & clock & chair...       cost   100  2926
# 123                 bus & person | cell_phone | bottle       cost   100   779
# 124               (book & bird) | traffic_light | bowl       cost   100   550
# 125  (bottle & dining_table) | (bowl & couch & car ...       cost   100   514
# 126               tennis_racket | (spoon & bowl) | tie       cost   100   415
#
#      accuracy   cost  total_cost  objective_accuracy objective_cost  \
# 0      0.9699  132.4       138.8              0.8761            110
# 1      0.7685  118.0       124.6              0.9412             82
# 2      0.7689  191.0       204.4              0.8991            150
# 3      0.5889  105.8       105.8              0.7546             70
# 4      0.6778  110.6       123.6              0.7101             96
# ..        ...    ...         ...                 ...            ...
# 122    0.9684    0.0         NaN              1.0000              0
# 123    0.8258    0.0         NaN              1.0000              0
# 124    0.8111    0.0         NaN              1.0000              0
# 125    0.8141    0.0         NaN              1.0000              0
# 126    0.8831    0.0         NaN              1.0000              0
#
#                                           result_index   approach
# 0    0,2,5,7,8,9,10,11,12,13,14,17,22,24,26,27,28,2...  basic_opt
# 1    2,10,11,17,22,33,46,47,48,49,50,61,63,65,75,82...  basic_opt
# 2    0,2,9,10,13,21,25,28,32,34,37,39,40,42,50,55,6...  basic_opt
# 3    9,10,65,110,111,112,114,123,132,160,162,208,31...  order_opt
# 4    9,10,42,65,96,110,111,112,114,119,123,160,162,...  basic_opt
# ..                                                 ...        ...
# 122  0,5,7,8,9,10,11,12,14,17,22,24,26,27,28,29,30,...         gt
# 123  2,10,11,15,17,22,33,46,48,49,50,61,63,65,75,93...         gt
# 124  13,22,28,37,55,75,85,89,96,100,111,137,145,146...         gt
# 125  13,25,28,32,33,39,40,75,82,93,95,96,103,104,10...         gt
# 126  8,9,22,27,28,42,43,47,54,55,64,83,85,86,95,108...         gt
#
# [127 rows x 13 columns]

# %%
df_result.to_csv('results/statistics_cost.csv')

# %% [markdown]
# ## Plot objectives vs. accu

# %%
from matplotlib.ticker import MaxNLocator

plt.rcParams['figure.dpi'] = 200

def scatter(df,ax,legend=False):
    
#     fig, ax = plt.subplots()
    for index,row in df.iterrows():
        ax.scatter(row.accu,row.objective_cost,label=row['approach'])
#     ax.xlabel("cost")
#     plt.ylabel('accuracy')
#     ax.set_ylim((0.5,1))
    if legend:
        ax.legend()
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# %%
subset = df_result[(df_result.query_index==0) & (df_result.constraint==constraint) & (df_result.bound==bound)]
subset
# Out:
#                        name query_index  \
# 4   base_0_overlap_cost_100           0
# 6      opt_0_order_cost_100           0
# 37   opt_0_overlap_cost_100           0
#
#                                                 query constraint bound  len  \
# 4   (baseball_bat & skis & refrigerator) | wine_glass       cost   100  132
# 6   (baseball_bat & skis & refrigerator) | wine_glass       cost   100  114
# 37  (baseball_bat & skis & refrigerator) | wine_glass       cost   100  151
#
#     accuracy   cost  total_cost  objective_accuracy objective_cost  \
# 4     0.9206  134.6       134.6              0.7445            131
# 6     0.8889  134.8       134.8              0.7799            114
# 37    0.9206  131.0       131.0              0.7613            136
#
#                                          result_index   approach
# 4   0,25,28,41,42,55,79,161,181,184,194,204,217,24...   baseline
# 6   0,25,28,41,42,55,79,161,181,184,204,217,247,29...  order_opt
# 37  0,25,28,41,42,55,79,148,161,181,184,194,204,21...  basic_opt

# %%
import numpy as np

def barplot(idx,subset,ax,y,legend=False):

    labels = ['baseline','basic_opt','order_opt']
#     subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    objective = []
    real = []
#     for i,row in subset.iterrows():
#     print(subset)
    for l in labels:
        objective.append(round(subset[subset.approach==l]['objective_'+y].values[0],2))
#         if y == 'cost':
#             obj = 'total_cost'
#         else:
#             obj = y
        obj = y
        real.append(round(subset[subset.approach==l][obj].values[0],2))


    x = np.arange(len(labels))  # the label locations
    width = 0.3  # the width of the bars
    
    rects1 = ax.bar(x - width/2, objective, width, label=labels[0])
    rects2 = ax.bar(x + width/2, real, width, label=labels[1])

    # Add some text for labels, title and custom x-axis tick labels, etc.
#     ax.set_ylabel('Accuracy')
    ax.set_title('Q'+str(idx+1))
    ax.set_xticks(x)
    ax.set_xticklabels(labels,rotation=45)
                   
    if y == 'accuracy':
        ax.set_yticks([0.1, 0.5, 1.0])
    else:
        ax.set_yticks([0,int(max(objective+real)*1.3)])
    
    if legend:
        ax.legend()

    ax.bar_label(rects1, padding=2,fontsize=6,label_type='edge')#edge
    ax.bar_label(rects2, padding=2,fontsize=6,label_type='edge')

# %%
constraint = 'cost'
bound = '50'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))
for idx in range(11):
#     print(idx)
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='accuracy',legend=False)
    except:
        continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Accuracy")

f.tight_layout()

# %%
constraint = 'cost'
bound = '50'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))

for idx in range(10):
#     print(idx)
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)
    except:
        continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Cost")
f.tight_layout()

# %%
constraint = 'cost'
bound = '100'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))

for idx in range(11):
#     print(idx)
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='accuracy',legend=False)
    except:continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Accuracy")
f.tight_layout()

# %%
constraint = 'cost'
bound = '150'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))

for idx in range(11):
#     print(idx)
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='accuracy',legend=False)
    except:continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Accuracy")
f.tight_layout()

# %%
constraint = 'cost'
bound = '150'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))

for idx in range(11):
#     print(idx)
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)
    except: continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Cost")
f.tight_layout()

# %% [markdown]
# ## Effect of constraints

# %%
import numpy as np

def barplot(idx,subset,ax,y,legend=False):
    
    if y == 'accuracy':
        gt = subset[subset['objective_cost']==0]['accuracy'].max()
        ax.hlines(y=gt, xmin=-0.5, xmax=2.5, linewidth=1.5, color='r')
    
    labels = ['baseline','basic_opt','order_opt']
    x_labels = ['50','100','150']
    v_base = []
    v_opt = []
    v_order = []
    for b in x_labels:
        v_base.append(round(subset[(subset.approach==labels[0]) & (subset.bound==b)][y].values[0],2))
        v_opt.append(round(subset[(subset.approach==labels[1]) & (subset.bound==b)][y].values[0],2))
        v_order.append(round(subset[(subset.approach==labels[2]) & (subset.bound==b)][y].values[0],2))

    x = np.arange(len(x_labels))  # the label locations
    width = 0.25  # the width of the bars
    
    rects1 = ax.bar(x - width, v_base, width, label=labels[0])
    rects2 = ax.bar(x, v_opt, width, label=labels[1])
    rects3 = ax.bar(x + width, v_order, width, label=labels[2])

    # Add some text for labels, title and custom x-axis tick labels, etc.
#     ax.set_ylabel('Accuracy')
    ax.set_title('Q'+str(idx+1))
    ax.set_xticks(x)
    if y == 'accuracy':
        ax.set_yticks([0.1, 0.5, 1.0])
    else:
        ax.set_yticks([0,110,220])
    ax.set_xticklabels(x_labels)
    if legend:
        ax.legend()

    ax.bar_label(rects1, padding=2,fontsize=6,label_type='edge')#edge
    ax.bar_label(rects2, padding=2,fontsize=6,label_type='edge')
    ax.bar_label(rects3, padding=2,fontsize=6,label_type='edge')
    
#     ax.grid()

# %%
constraint = 'cost'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))

for idx in range(11):
#     print(idx)
#     print(queryList[idx])
    
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='accuracy',legend=False)
    except:continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Accuracy")
f.tight_layout()

# %%
constraint = 'cost'
ncols = 4
f, axes = plt.subplots(nrows = 3, ncols = ncols, sharex=True, sharey = True,figsize=(9,6))

for idx in range(11):
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint)]
    try:
        barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)
    except:continue

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Cost")
f.tight_layout()

# %%
df_result[(df_result.query_index==3) & (df_result.constraint=='cost') & (df_result.bound=='150')]
# Out:
#                        name query_index                               query  \
# 14  base_3_overlap_cost_150           3  handbag & person | train & bicycle
# 27     opt_3_order_cost_150           3  handbag & person | train & bicycle
# 28   opt_3_overlap_cost_150           3  handbag & person | train & bicycle
# 42                 yolov5x6           3  handbag & person | train & bicycle
# 46                   yolov3           3  handbag & person | train & bicycle
# 50                 yolov5m6           3  handbag & person | train & bicycle
# 54                  yolov5m           3  handbag & person | train & bicycle
# 58                  yolov5x           3  handbag & person | train & bicycle
#
#    constraint bound  len  accuracy   cost  total_cost  objective_accuracy  \
# 14       cost   150  308    0.7056  192.0       192.0              0.7407
# 27       cost   150  241    0.5944  174.4       174.4              0.7546
# 28       cost   150  239    0.5944  155.6       155.6              0.7529
# 42       cost   150  242    0.6056    0.0         NaN              1.0000
# 46       cost   150  210    0.5500    0.0         NaN              1.0000
# 50       cost   150  210    0.5611    0.0         NaN              1.0000
# 54       cost   150  218    0.5667    0.0         NaN              1.0000
# 58       cost   150  281    0.6778    0.0         NaN              1.0000
#
#    objective_cost                                       result_index  \
# 14            147  9,10,42,65,96,110,111,112,114,119,123,132,160,...
# 27            129  9,10,65,110,111,112,114,123,132,160,162,208,31...
# 28            129  9,10,65,110,111,112,114,123,132,160,162,208,31...
# 42              0  9,10,65,110,111,112,114,123,132,160,162,208,31...
# 46              0  9,10,42,112,114,119,123,160,162,208,245,286,31...
# 50              0  9,10,65,96,110,111,112,114,123,160,162,223,313...
# 54              0  9,10,42,65,74,99,111,112,114,123,160,162,208,3...
# 58              0  9,10,33,42,74,88,99,110,111,112,114,123,132,13...
#
#      approach
# 14   baseline
# 27  order_opt
# 28  basic_opt
# 42         gt
# 46         gt
# 50         gt
# 54         gt
# 58         gt

# %%
constraint = 'cost'
ncols = 3
f, axes = plt.subplots(nrows = 2, ncols = ncols, sharex=True, sharey = True,figsize=(9,4))

for idx in range(5):
    print(idx)
    print(queryList[idx])
    
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint)]
    barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Cost")
f.tight_layout()
# Out:
# 0
# (baseball_bat & skis & refrigerator) | wine_glass
# 1
# book | person
# 2
# cup & person & remote | bird
# 3
# handbag & person | train & bicycle
# 4
# dining_table | person & clock | handbag

# %% [markdown]
# ## Model assignment

# %%
df_record.head()
# Out:
#    query_index  qgetSelectivityuery  #predicate    mdist    qdist constraint  \
# 0            1                  NaN           2  uniform  uniform       cost
# 1            1                  NaN           2  uniform  uniform       cost
# 2            0                  NaN           4  uniform  uniform       cost
# 3            0                  NaN           4  uniform  uniform       cost
# 4            7                  NaN           4  uniform  uniform       cost
#
#    bound   approach                                     selected_model  \
# 0  150.0  optimizer                      person.model_41|book.model_82
# 1  100.0  optimizer                      person.model_41|book.model_82
# 2  150.0  optimizer  refrigerator.model_72|wine_glass.model_41|skis...
# 3  100.0  optimizer  refrigerator.model_72|wine_glass.model_41|base...
# 4  150.0  optimizer  bird.model_133|traffic_light.model_66|bowl.mod...
#
#                                         pareto_model  #pareto  \
# 0                      person.model_41|book.model_82        2
# 1                      person.model_41|book.model_82        2
# 2  refrigerator.model_72|wine_glass.model_41|skis...        4
# 3  refrigerator.model_72|wine_glass.model_41|base...        4
# 4                                     bird.model_133        1
#
#                                     non_pareto_model  #non_pareto  \
# 0                                                NaN            0
# 1                                                NaN            0
# 2                                                NaN            0
# 3                                                NaN            0
# 4  traffic_light.model_66|bowl.model_78|book.mode...            3
#
#    pareto_ratio  accuracy        cost  optimization_time  data_process_time  \
# 0          1.00  0.876100   91.748800             0.0315             0.0042
# 1          1.00  0.876100   91.748800             0.0311             0.0038
# 2          1.00  0.779860  114.529885             0.1234             0.1204
# 3          1.00  0.777970   89.557895             0.2641             0.1184
# 4          0.25  0.887291  135.390400             0.6273             0.0048
#
#                                                query
# 0                                      book | person
# 1                                      book | person
# 2  (baseball_bat & skis & refrigerator) | wine_glass
# 3  (baseball_bat & skis & refrigerator) | wine_glass
# 4               (book & bird) | traffic_light | bowl

# %%
bound = 150
approach = ['baseline','basic_opt','order_opt']
df_ = [df_baseline,df_opt,df_order_opt]

for idx in range(4):
    print('=============')
    print('query '+str(idx))
    for i,app in enumerate(approach):
        print('***')
        print(app)
        print('***')
        df_record = df_[i]
        subset = df_record[(df_record.query_index==idx) & (df_record['bound']==bound)]
        print(subset['query'].values[0])
        selected_model = subset.selected_model.values[0]
        assignment = {item.split('.')[0].replace('_',' '):item.split('.')[1] for item in selected_model.split('|')}
        print(assignment)
        for k,v in assignment.items():
            print(k,v)
            print(df_model.loc[v,k])
        print('---------')
# Out:
# =============
# query 0
# ***
# baseline
# ***
# (baseball_bat & skis & refrigerator) | wine_glass
# {'wine glass': 'model_38', 'skis': 'model_30', 'baseball bat': 'model_30', 'refrigerator': 'model_72'}
# wine glass model_38
# 0.63
# skis model_30
# 0.68
# baseball bat model_30
# 0.65
# refrigerator model_72
# 0.7
# ---------
# ***
# basic_opt
# ***
# (baseball_bat & skis & refrigerator) | wine_glass
# {'wine glass': 'model_41', 'refrigerator': 'model_108', 'skis': 'model_66', 'baseball bat': 'model_66'}
# wine glass model_41
# 0.64
# refrigerator model_108
# 0.67
# skis model_66
# 0.74
# baseball bat model_66
# 0.69
# ---------
# ***
# order_opt
# ***
# (baseball_bat & skis & refrigerator) | wine_glass
# {'refrigerator': 'model_72', 'wine glass': 'model_41', 'skis': 'model_66', 'baseball bat': 'model_89'}
# refrigerator model_72
# 0.7
# wine glass model_41
# 0.64
# skis model_66
# 0.74
# baseball bat model_89
# 0.75
# ---------
# =============
# query 1
# ***
# baseline
# ***
# book | person
# {'person': 'model_41', 'book': 'model_82'}
# person model_41
# 0.79
# book model_82
# 0.41
# ---------
# ***
# basic_opt
# ***
# book | person
# {'person': 'model_41', 'book': 'model_82'}
# person model_41
# 0.79
# book model_82
# 0.41
# ---------
# ***
# order_opt
# ***
# book | person
# {'person': 'model_41', 'book': 'model_82'}
# person model_41
# 0.79
# book model_82
# 0.41
# ---------
# =============
# query 2
# ***
# baseline
# ***
# cup & person & remote | bird
# {'person': 'model_44', 'cup': 'model_90', 'bird': 'model_90', 'remote': 'model_141'}
# person model_44
# 0.77
# cup model_90
# 0.66
# bird model_90
# 0.52
# remote model_141
# 0.65
# ---------
# ***
# basic_opt
# ***
# cup & person & remote | bird
# {'bird': 'model_133', 'cup': 'model_90', 'person': 'model_141', 'remote': 'model_141'}
# bird model_133
# 0.53
# cup model_90
# 0.66
# person model_141
# 0.78
# remote model_141
# 0.65
# ---------
# ***
# order_opt
# ***
# cup & person & remote | bird
# {'bird': 'model_133', 'remote': 'model_86', 'person': 'model_41', 'cup': 'model_90'}
# bird model_133
# 0.53
# remote model_86
# 0.65
# person model_41
# 0.79
# cup model_90
# 0.66
# ---------
# =============
# query 3
# ***
# baseline
# ***
# handbag & person | train & bicycle
# {'train': 'model_140', 'person': 'model_41', 'handbag': 'model_78', 'bicycle': 'model_78'}
# train model_140
# 0.83
# person model_41
# 0.79
# handbag model_78
# 0.45
# bicycle model_78
# 0.72
# ---------
# ***
# basic_opt
# ***
# handbag & person | train & bicycle
# {'train': 'model_141', 'person': 'model_141', 'bicycle': 'model_78', 'handbag': 'model_78'}
# train model_141
# 0.86
# person model_141
# 0.78
# bicycle model_78
# 0.72
# handbag model_78
# 0.45
# ---------
# ***
# order_opt
# ***
# handbag & person | train & bicycle
# {'person': 'model_41', 'train': 'model_141', 'bicycle': 'model_78', 'handbag': 'model_78'}
# person model_41
# 0.79
# train model_141
# 0.86
# bicycle model_78
# 0.72
# handbag model_78
# 0.45
# ---------

# %%
bound = 100
approach = ['baseline','basic_opt','order_opt']
df_ = [df_baseline,df_opt,df_order_opt]

for idx in range(4):
    print('=============')
    print('query '+str(idx))
    for i,app in enumerate(approach):
        print('***')
        print(app)
        print('***')
        df_record = df_[i]
        subset = df_record[(df_record.query_index==idx) & (df_record['bound']==bound)]
        print(subset['query'].values[0])
        selected_model = subset.selected_model.values[0]
        assignment = {item.split('.')[0].replace('_',' '):item.split('.')[1] for item in selected_model.split('|')}
        print(assignment)
        for k,v in assignment.items():
            print(k,v)
            print(df_model.loc[v,k])
        print('---------')
# Out:
# =============
# query 0
# ***
# baseline
# ***
# (baseball_bat & skis & refrigerator) | wine_glass
# {'wine glass': 'model_38', 'skis': 'model_30', 'baseball bat': 'model_30', 'refrigerator': 'model_108'}
# wine glass model_38
# 0.63
# skis model_30
# 0.68
# baseball bat model_30
# 0.65
# refrigerator model_108
# 0.67
# ---------
# ***
# basic_opt
# ***
# (baseball_bat & skis & refrigerator) | wine_glass
# {'skis': 'model_38', 'wine glass': 'model_38', 'refrigerator': 'model_44', 'baseball bat': 'model_90'}
# skis model_38
# 0.66
# wine glass model_38
# 0.63
# refrigerator model_44
# 0.66
# baseball bat model_90
# 0.72
# ---------
# ***
# order_opt
# ***
# (baseball_bat & skis & refrigerator) | wine_glass
# {'refrigerator': 'model_72', 'wine glass': 'model_41', 'baseball bat': 'model_89', 'skis': 'model_55'}
# refrigerator model_72
# 0.7
# wine glass model_41
# 0.64
# baseball bat model_89
# 0.75
# skis model_55
# 0.73
# ---------
# =============
# query 1
# ***
# baseline
# ***
# book | person
# {'book': 'model_138', 'person': 'model_41'}
# book model_138
# 0.4
# person model_41
# 0.79
# ---------
# ***
# basic_opt
# ***
# book | person
# {'person': 'model_41', 'book': 'model_138'}
# person model_41
# 0.79
# book model_138
# 0.4
# ---------
# ***
# order_opt
# ***
# book | person
# {'person': 'model_41', 'book': 'model_82'}
# person model_41
# 0.79
# book model_82
# 0.41
# ---------
# =============
# query 2
# ***
# baseline
# ***
# cup & person & remote | bird
# {'person': 'model_44', 'remote': 'model_44', 'cup': 'model_90', 'bird': 'model_90'}
# person model_44
# 0.77
# remote model_44
# 0.58
# cup model_90
# 0.66
# bird model_90
# 0.52
# ---------
# ***
# basic_opt
# ***
# cup & person & remote | bird
# {'remote': 'model_126', 'cup': 'model_90', 'bird': 'model_90', 'person': 'model_90'}
# remote model_126
# 0.64
# cup model_90
# 0.66
# bird model_90
# 0.52
# person model_90
# 0.75
# ---------
# ***
# order_opt
# ***
# cup & person & remote | bird
# {'bird': 'model_133', 'remote': 'model_86', 'person': 'model_41', 'cup': 'model_90'}
# bird model_133
# 0.53
# remote model_86
# 0.65
# person model_41
# 0.79
# cup model_90
# 0.66
# ---------
# =============
# query 3
# ***
# baseline
# ***
# handbag & person | train & bicycle
# {'person': 'model_44', 'handbag': 'model_44', 'bicycle': 'model_44', 'train': 'model_141'}
# person model_44
# 0.77
# handbag model_44
# 0.38
# bicycle model_44
# 0.62
# train model_141
# 0.86
# ---------
# ***
# basic_opt
# ***
# handbag & person | train & bicycle
# {'bicycle': 'model_133', 'handbag': 'model_133', 'train': 'model_140', 'person': 'model_44'}
# bicycle model_133
# 0.7
# handbag model_133
# 0.4
# train model_140
# 0.83
# person model_44
# 0.77
# ---------
# ***
# order_opt
# ***
# handbag & person | train & bicycle
# {'person': 'model_41', 'train': 'model_141', 'handbag': 'model_78', 'bicycle': 'model_78'}
# person model_41
# 0.79
# train model_141
# 0.86
# handbag model_78
# 0.45
# bicycle model_78
# 0.72
# ---------

# %% [markdown]
# ## Cost = 100

# %%
import glob
import re
import pandas as pd
from sympy.parsing.sympy_parser import parse_expr

constraint = 'cost'

df_result_100 = pd.DataFrame(columns=['name','query_index','query','constraint','bound',\
                                  'len','accuracy','cost','total_cost','objective_accuracy','objective_cost','result_index'])

# %%
folder = 'tables/'
for file in glob.glob(folder+"*"):
    print(file)
    df = pd.read_csv(file)
    print(df.shape)
    
    name = file.split('/')[-1].split('.')[0]
    print('name',name)
    if len(name.split('_')) < 4:
        continue

    if not df_result_100[df_result_100['name'] == name].empty:
        continue
    
    # retrieve cost
    total_cost = df_cost[(df_cost['experiment']=='script_'+name) & (df_cost['duration']>10)]['duration'].sum()/5
#     cost = df_cost[(df_cost['experiment']=='script_'+name)]['duration'][::-2].sum()-10
    subset = df_cost[(df_cost['experiment']=='script_'+name)]
    s = list(subset.sort_values(by=['startedAt'])['duration'][2:]) # [2,3,::2]
    
#     cost = sum([s[0]]+s[1:][::2]) / 5
    cost = total_cost
    print('cost',cost)

    order = name.split('_')[2] == 'order'
    print('order',order)
    
    query_idx = int(re.search(r'\d+', name).group(0))
    print(query_idx)
    
    consr_type = re.search(r'.*_([a-z]+)_.*', name).group(1)
    if consr_type != constraint:
        continue
        
    bound = re.search(r'.*_(\d+)', name).group(1)
    query = queryList[query_idx]
    
    if order:
        df_record = df_order_opt
        approach = 'order_opt'
    elif name[:3] == 'opt':
        df_record = df_opt
        approach = 'basic_opt'
    else:
        df_record = df_baseline
        approach = 'baseline'
        
    # Match objective value with extracted accuracy results
    record = df_record[(df_record['query_index']==query_idx) & (df_record['constraint']==consr_type)]
    
    index = getImageIndex(query,df)
    gt = list(filter(lambda x: x>=2000, indexList[query_idx]))
    label = list(filter(lambda x: x>=2000,index))
    intersection = list(set.intersection(set(gt), set(label)))
    
    print('intersect',len(intersection))
    print('total',len(gt))
    
    accu = len(intersection)/len(gt)
    print('accu',accu)
    result_idx = ','.join([str(i) for i in index])

    new_row = pd.DataFrame([{'name':name,'query_index':query_idx,'query':query,\
                             'constraint':constraint,'bound':bound,'approach':approach,'len':len(index),\
                             'accuracy':round(accu,4),'cost':cost,'total_cost':total_cost,'objective_accuracy':round(record.accuracy.values[0],4),\
                             'objective_cost':int(record['cost'].values[0]),'result_index':result_idx}])
#     print(new_row)
    df_result_100 = df_result_100.append(new_row, ignore_index=True)
    
    print('----------')
    print()
# Out:
# tables/base_5_overlap_cost_100.csv
# (5000, 82)
# name base_5_overlap_cost_100
# cost 121.4
# order False
# 5
# ['chair', 'tennis_racket', 'sink', 'truck', 'handbag', 'bus', 'clock', 'person']
# len(index) 2807
# intersect 1605
# total 1741
# accu 0.9218839747271683
# ----------
#
# tables/base_0_overlap_cost_100.csv
# (5000, 82)
# name base_0_overlap_cost_100
# cost 134.6
# order False
# 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 132
# intersect 58
# total 63
# accu 0.9206349206349206
# ----------
#
# tables/opt_0_order_cost_100.csv
# (5000, 82)
# name opt_0_order_cost_100
# cost 134.8
# order True
# 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 114
# intersect 56
# total 63
# accu 0.8888888888888888
# ----------
#
# tables/base_4_overlap_cost_100.csv
# (5000, 82)
# name base_4_overlap_cost_100
# cost 88.8
# order False
# 4
# ['dining_table', 'clock', 'handbag', 'person']
# len(index) 925
# intersect 373
# total 489
# accu 0.7627811860940695
# ----------
#
# tables/base_1_overlap_cost_100.csv
# (5000, 82)
# name base_1_overlap_cost_100
# cost 114.8
# order False
# 1
# ['person', 'book']
# len(index) 2752
# intersect 1577
# total 1692
# accu 0.932033096926714
# ----------
#
# tables/base_2_overlap_cost_100.csv
# (5000, 82)
# name base_2_overlap_cost_100
# cost 85.2
# order False
# 2
# ['bird', 'person', 'remote', 'cup']
# len(index) 181
# intersect 67
# total 80
# accu 0.8375
# ----------
#
# tables/base_3_overlap_cost_100.csv
# (5000, 82)
# name base_3_overlap_cost_100
# cost 110.0
# order False
# 3
# ['bicycle', 'handbag', 'train', 'person']
# len(index) 217
# intersect 96
# total 180
# accu 0.5333333333333333
# ----------
#
# tables/opt_1_order_cost_100.csv
# (5000, 82)
# name opt_1_order_cost_100
# cost 110.6
# order True
# 1
# ['person', 'book']
# len(index) 2882
# intersect 1643
# total 1692
# accu 0.9710401891252955
# ----------
#
# tables/opt_0_overlap_cost_100.csv
# (5000, 82)
# name opt_0_overlap_cost_100
# cost 131.0
# order False
# 0
# ['wine_glass', 'skis', 'refrigerator', 'baseball_bat']
# len(index) 151
# intersect 58
# total 63
# accu 0.9206349206349206
# ----------

# %%
folder = 'tables/'

for file in glob.glob(folder+'yolov*.csv'):
    
    df = pd.read_csv(file)

    name = file.split('/')[-1].split('.')[0]
    print('name',name)

    # retrieve cost
    cost = df_cost[(df_cost['experiment']=='script_'+name) & (df_cost['duration']>10)]['duration'].sum()
    cost = cost / 5
    print('cost',cost)

    for i in range(4):
        query = queryList[i]
        index = getImageIndex(query,df)
        gt = list(filter(lambda x: x>=2000, indexList[i]))
        label = list(filter(lambda x: x>=2000,index))
        intersection = list(set.intersection(set(gt), set(label)))
        print('intersect',len(intersection))
        print('total',len(gt))
        accu = len(intersection)/len(gt)
        print('accu',accu)
        result_idx = ','.join([str(i) for i in index])

        new_row = pd.DataFrame([{'name':name,'query_index':i,'query':query,\
                                 'constraint':'cost','bound':bound,'approach':'gt','len':len(index),\
                                 'accuracy':round(accu,4),'cost':cost,'objective_accuracy':1.0,\
                                 'objective_cost':0,'result_index':result_idx}])
    #     print(new_row)
        df_result_100 = df_result_100.append(new_row, ignore_index=True)

        print('----------')
        print()

# %%
constraint = 'cost'
bound = '100'
ncols = 2
f, axes = plt.subplots(nrows = 2, ncols = ncols, sharex=True, sharey = True,figsize=(9,4))

for idx in range(3):
    print(idx)
    subset = df_result_100[(df_result_100.query_index==idx) & (df_result_100.constraint==constraint) & (df_result_100.bound==bound)]
    barplot(idx,subset,axes[idx//ncols, idx%ncols],y='accuracy',legend=False)

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Accuracy")
f.tight_layout()
# Out:
# 0
# [0.74, 0.76, 0.78] [0.92, 0.92, 0.89]
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-89-88c70677d150> in <module>
#       7     print(idx)
#       8     subset = df_result_100[(df_result_100.query_index==idx) & (df_result_100.constraint==constraint) & (df_result_100.bound==bound)]
# ----> 9     barplot(idx,subset,axes[idx//ncols, idx%ncols],y='accuracy',legend=False)
#      10
#      11 f.add_subplot(111, frame_on=False)
#
# <ipython-input-70-75272b775298> in barplot(idx, subset, ax, y, legend)
#      10 #     print(subset)
#      11     for l in labels:
# ---> 12         objective.append(round(subset[subset.approach==l]['objective_'+y].values[0],2))
#      13         real.append(round(subset[subset.approach==l][y].values[0],2))
#      14
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
constraint = 'cost'
bound = '100'
ncols = 2
f, axes = plt.subplots(nrows = 2, ncols = ncols, sharex=True, sharey = True,figsize=(9,4))

for idx in range(3):
    print(idx)
    subset = df_result_100[(df_result_100.query_index==idx) & (df_result_100.constraint==constraint) & (df_result_100.bound==bound)]
    barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Cost")
f.tight_layout()
# Out:
# 0
# [131, 136, 114] [134.6, 131.0, 134.8]
# 1
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-90-f957124d2527> in <module>
#       7     print(idx)
#       8     subset = df_result_100[(df_result_100.query_index==idx) & (df_result_100.constraint==constraint) & (df_result_100.bound==bound)]
# ----> 9     barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)
#      10
#      11 f.add_subplot(111, frame_on=False)
#
# <ipython-input-70-75272b775298> in barplot(idx, subset, ax, y, legend)
#      10 #     print(subset)
#      11     for l in labels:
# ---> 12         objective.append(round(subset[subset.approach==l]['objective_'+y].values[0],2))
#      13         real.append(round(subset[subset.approach==l][y].values[0],2))
#      14
#
# IndexError: index 0 is out of bounds for axis 0 with size 0

# %%
constraint = 'cost'
bound = '150'
ncols = 5
f, axes = plt.subplots(nrows = 2, ncols = ncols, sharex=True, sharey = True,figsize=(9,4))

for idx in range(10):
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    barplot(idx,subset,axes[idx//ncols, idx%ncols],y='cost',legend=False)

f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.ylabel("Cost")
f.tight_layout()
# Out:
# [107, 107, 58] [127.6, 127.0, 77.4]
# [147, 148, 147] [180.8, 174.8, 176.2]
# [125, 126, 131] [151.8, 155.8, 128.6]
# [127, 145, 129] [154.6, 180.2, 158.4]
# [148, 138, 117] [149.2, 173.4, 156.6]
# [150, 137, 145] [190.8, 171.6, 190.0]
# [128, 143, 142] [153.4, 171.0, 179.8]
# [146, 140, 139] [151.4, 174.0, 166.8]
# [149, 150, 119] [159.4, 186.6, 201.6]
# [138, 136, 149] [170.2, 165.8, 193.2]

# %% [markdown]
# ## Plot accu vs. cost

# %%
from matplotlib.ticker import MaxNLocator

plt.rcParams['figure.dpi'] = 200

def scatter(idx,df,ax,legend=False):
    
    gt = df[df['objective_cost']==0]['accuracy'].max()
    ax.hlines(y=gt, xmin=0, xmax=200, linewidth=1.5, color='r')
    
    labels = ['baseline','basic_opt','order_opt']
    objective = []
    real = []
    for l in labels:
        row = df[df.approach==l]
        ax.scatter(row.cost.values[0],row.accuracy.values[0],label=l)
    
    ax.set_xticks([0,100,200])
    ax.set_xticklabels([0,100,200],fontsize=11)
#     ax.set_yticks([0.5, 0.75, 1.0])
    ax.set_title('Q'+str(idx+1))
#     ax.set_ylim((0.5,1))
    if legend:
        ax.legend()
#     ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# %%
constraint = 'cost'
bound = '150'
ncols = 2
f, axes = plt.subplots(nrows = 2, ncols = ncols, sharex=True, sharey = True,figsize=(9,5))
# plt.setp(axes, xticks=[0.1, 0.5, 1.2],yticks=[128,170,220])

for idx in range(3):
    subset = df_result[(df_result.query_index==idx) & (df_result.constraint==constraint) & (df_result.bound==bound)]
    scatter(idx,subset,axes[idx//ncols, idx%ncols],legend=True)
    
f.add_subplot(111, frame_on=False)
plt.tick_params(labelcolor="none", bottom=False, left=False)
plt.xlabel("Cost")
plt.ylabel("Accuracy")
f.tight_layout()

# %% [markdown]
# ## Retrieve task name

# %%
names = ['person', 'bicycle', 'car', 'motorcycle', 'airplane', 'bus', 'train', 'truck', \
			'boat', 'traffic light', 'fire hydrant', 'stop sign', 'parking meter', 'bench', \
			'bird', 'cat', 'dog', 'horse', 'sheep', 'cow', 'elephant', 'bear', 'zebra', 'giraffe', \
			'backpack', 'umbrella', 'handbag', 'tie', 'suitcase', 'frisbee', 'skis', 'snowboard', \
			'sports ball', 'kite', 'baseball bat', 'baseball glove', 'skateboard', 'surfboard', \
			'tennis racket', 'bottle', 'wine glass', 'cup', 'fork', 'knife', 'spoon', 'bowl', \
			'banana', 'apple', 'sandwich', 'orange', 'broccoli', 'carrot', 'hot dog', 'pizza', \
			'donut', 'cake', 'chair', 'couch', 'potted plant', 'bed', 'dining table', 'toilet', \
			'tv', 'laptop', 'mouse', 'remote', 'keyboard', 'cell phone', 'microwave', 'oven', \
			'toaster', 'sink', 'refrigerator', 'book', 'clock', 'vase', 'scissors', 'teddy bear', 'toothbrush']

# %%
len(names)
# Out:
# 79

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer','order_opt']


def load_cost(m_dist,q_dist,approach):
    filepath = 'output/summary_cost_'+m_dist+'_'+q_dist+'_'+approach+'.csv'
    if approach == 'order_opt':
        filepath = 'output/summary_order_cost_'+m_dist+'_'+q_dist+'_optimizer.csv'
    try:
        df = pd.read_csv(filepath,index_col=0)
    except Exception as e:
        filepath = 'output/summary_cost_'+m_dist+'_'+q_dist+'_'+approach+'_a=5.csv'
        df = pd.read_csv(filepath,index_col=0)
        
    print(df.shape)
#     print(df.head())
    return df

df_list = []
label_list = []
for q in q_dist:
    for m in m_dist:
        for app in approach:
            df_list.append(load_cost(m,q,app))
            if app == 'baseline_pareto':
                app = 'baseline'
            label_list.append(app+'_'+m+'_'+q)
print(label_list)

# %%
plt.rcParams['figure.dpi'] = 100
fig, ax = plt.subplots()

for i in range(len(df_list)):
    ax.scatter(df_list[i]['cost'], df_list[i]['accuracy'],label=label_list[i])

plt.ylabel('Accuracy')
plt.xlabel('Cost')
plt.title('Performance of query results when cost is constrained')
plt.legend()

# %%
# q_dist = ['uniform','power_law']
# m_dist = q_dist
# approach = ['baseline_pareto','optimizer']


# def load_cost(m_dist,q_dist,approach):
#     filepath = 'output/summary_cost_'+m_dist+'_'+q_dist+'_'+approach+'.csv'
#     try:
#         df = pd.read_csv(filepath,index_col=0)
#     except Exception as e:
#         filepath = 'output/summary_cost_'+m_dist+'_'+q_dist+'_'+approach+'_a=5.csv'
#         df = pd.read_csv(filepath,index_col=0)

#     print(df.shape)
# #     print(df.head())
#     return df

# df_list = []
# label_list = []
# for q in q_dist:
#     for m in m_dist:
#         for app in approach:
#             df_list.append(load_cost(m,q,app))
#             if app == 'baseline_pareto':
#                 app = 'baseline'
#             label_list.append(app+'_'+m+'_'+q)
# print(label_list)

# %%
# plt.rcParams['figure.dpi'] = 100
# fig, ax = plt.subplots()

# for i in range(len(df_list)):
#     ax.scatter(df_list[i]['cost'], df_list[i]['accuracy'],label=label_list[i])

# plt.ylabel('Accuracy')
# plt.xlabel('Cost')
# plt.title('Performance of query results when cost is constrained')
# # plt.yscale('logit')
# plt.legend()

# %% [markdown]
# ### Boxplot on the objective dimension: accuracy

# %%
def boxplot(com_dists,data,max_y=0,ylabel='Accuracy',constraint='Cost',size=14,path='',x_offset=0,y_offset=0):
    fig, ax1 = plt.subplots(figsize=(7, 6))
    fig.canvas.set_window_title('A Boxplot Example')
    fig.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)

    bp = ax1.boxplot(data, notch=0, sym='+', vert=1, whis=1.5)
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['fliers'], color='red', marker='+')

    # Add a horizontal grid to the plot, but make it very light in color
    # so we can use it for reading data values but not be distracting
    ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
                   alpha=0.5)

    ax1.set(
        axisbelow=True,  # Hide the grid behind plot objects
#         title=ylabel+' of query results when '+constraint+' is constrained',
        xlabel='Combinations (m_dist:q_dist)',
        ylabel=ylabel,
    )
    ax1.xaxis.get_label().set_fontsize(size)
    ax1.yaxis.get_label().set_fontsize(size)

    # Now fill the boxes with desired colors
    box_colors = ['#2694ab', '#e59572']
    num_boxes = len(data)
    medians = np.empty(num_boxes)
    means = [np.mean(x) for x in data]
#     print(means)
    # pylab.scatter(range(1,len(data)+1), means)

    for i in range(num_boxes):
        box = bp['boxes'][i]
        box_x = []
        box_y = []
        for j in range(5):
            box_x.append(box.get_xdata()[j])
            box_y.append(box.get_ydata()[j])
        box_coords = np.column_stack([box_x, box_y])
        # Alternate between Dark Khaki and Royal Blue
        ax1.add_patch(Polygon(box_coords, facecolor=box_colors[i % 2]))
        # Now draw the median lines back over what we just filled in
        med = bp['medians'][i]
        median_x = []
        median_y = []
        for j in range(2):
            median_x.append(med.get_xdata()[j])
            median_y.append(med.get_ydata()[j])
            ax1.plot(median_x, median_y, 'k')
        medians[i] = median_y[0]
        # Finally, overplot the sample averages, with horizontal alignment
        # in the center of each box
        ax1.plot(np.average(med.get_xdata()), np.average(data[i]),
                 color='w', marker='X', markeredgecolor='k',markersize=10)

    # Set the axes ranges and axes labels
    ax1.set_xlim(0.5, num_boxes + 0.5)
    top = max_y * 1.1
    bottom = 0
    ax1.set_ylim(bottom, top)
    ax1.set_xticklabels(np.repeat(comb_dists, 2),
                        rotation=45, fontsize=size)
    ax1.tick_params(labelsize=size)

    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(num_boxes) + 1
    # upper_labels = [str(round(s, 2)) for s in medians]
    upper_labels = [str(round(s, 3)) for i,s in enumerate(means)]
    weights = ['bold', 'semibold']
    for tick, label in zip(range(num_boxes), ax1.get_xticklabels()):
        k = tick % 2
        ax1.text(pos[tick], .95, upper_labels[tick],
                 transform=ax1.get_xaxis_transform(),
                 horizontalalignment='center', size='medium',
                 weight=weights[k], color=box_colors[k])
    # Valid font size are xx-small, x-small, small, medium, large, x-large, xx-large, larger, smaller, None
    # Finally, add a basic legend
    fig.text(0.79-x_offset, 0.461-y_offset, 'Baseline',
             backgroundcolor=box_colors[0], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.417-y_offset, 'Optimizer',
             backgroundcolor=box_colors[1],
             color='white', weight='roman', size='medium')
    fig.text(0.79-x_offset, 0.374-y_offset, 'x', color='white', backgroundcolor='silver',
             weight='roman', size='medium')
    fig.text(0.81-x_offset, 0.374-y_offset, ' Avg.', color='black', weight='roman',
             size='medium')
    plt.tight_layout()
    
    plt.savefig(path,format='eps')

    plt.show()

# %%
comb_dists = []
data = []
i=0
for q in q_dist:
    for m in m_dist:
        comb_dists.append(m+':'+q)
        for app in approach:
            data.append(df_list[i]['accuracy'])
            i+=1
print(comb_dists)
ylabel='Accuracy'
constraint='cost'
print(ylabel+' of query results when '+constraint+' is constrained')
boxplot(comb_dists,data,max_y=max(data[0]),
        ylabel='Accuracy',constraint='cost',
       path="image/accuacy_vs_approaches_constraint_cost.eps")

# %% [markdown]
# ## Boxplot two optimizer

# %%
def boxplot(com_dists,data,max_y=0,ylabel='Accuracy',constraint='Cost',size=14,path='',x_offset=0,y_offset=0):
    fig, ax1 = plt.subplots(figsize=(9, 6))
    fig.canvas.set_window_title('A Boxplot Example')
    fig.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)

    bp = ax1.boxplot(data, notch=0, sym='+', vert=1, whis=1.5)
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['fliers'], color='red', marker='+')

    # Add a horizontal grid to the plot, but make it very light in color
    # so we can use it for reading data values but not be distracting
    ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
                   alpha=0.5)

    ax1.set(
        axisbelow=True,  # Hide the grid behind plot objects
#         title=ylabel+' of query results when '+constraint+' is constrained',
        xlabel='Combinations (m_dist:q_dist)',
        ylabel=ylabel,
    )
    ax1.xaxis.get_label().set_fontsize(size)
    ax1.yaxis.get_label().set_fontsize(size)

    # Now fill the boxes with desired colors
    box_colors = ['#2694ab', '#e59572','#e16162']
    num_boxes = len(data)
    medians = np.empty(num_boxes)
    means = [np.mean(x) for x in data]
#     print(means)
    # pylab.scatter(range(1,len(data)+1), means)
    print('num_boxes',num_boxes)
    for i in range(num_boxes):
        box = bp['boxes'][i]
        box_x = []
        box_y = []
#         print(box.get_xdata())
#         print(box.get_ydata())
        for j in range(5):
            box_x.append(box.get_xdata()[j])
            box_y.append(box.get_ydata()[j])
        box_coords = np.column_stack([box_x, box_y])
        # Alternate between Dark Khaki and Royal Blue
        ax1.add_patch(Polygon(box_coords, facecolor=box_colors[i % 3]))
        # Now draw the median lines back over what we just filled in
        med = bp['medians'][i]
        median_x = []
        median_y = []
        for j in range(2):
            median_x.append(med.get_xdata()[j])
            median_y.append(med.get_ydata()[j])
            ax1.plot(median_x, median_y, 'k')
        medians[i] = median_y[0]
        # Finally, overplot the sample averages, with horizontal alignment
        # in the center of each box
        ax1.plot(np.average(med.get_xdata()), np.average(data[i]),
                 color='w', marker='X', markeredgecolor='k',markersize=10)

    # Set the axes ranges and axes labels
    ax1.set_xlim(0.5, num_boxes + 0.5)
    top = max_y * 1.03
    bottom = 0.7
    ax1.set_ylim(bottom, top)
    ax1.set_xticklabels(np.repeat(comb_dists, 3),
                        rotation=45, fontsize=size)
    ax1.tick_params(labelsize=size)

    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(num_boxes) + 1
    # upper_labels = [str(round(s, 2)) for s in medians]
    upper_labels = [str(round(s, 3)) for i,s in enumerate(means)]
    weights = ['bold', 'semibold','semibold']
    for tick, label in zip(range(num_boxes), ax1.get_xticklabels()):
        k = tick % 3
        ax1.text(pos[tick], .95, upper_labels[tick],
                 transform=ax1.get_xaxis_transform(),
                 horizontalalignment='center', size='medium',
                 weight=weights[k], color=box_colors[k])
    # Valid font size are xx-small, x-small, small, medium, large, x-large, xx-large, larger, smaller, None
    # Finally, add a basic legend
    fig.text(0.79-x_offset, 0.5-y_offset, 'Baseline',
             backgroundcolor=box_colors[0], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.461-y_offset, 'Optimizer',
             backgroundcolor=box_colors[1], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.417-y_offset, 'Order_Opt',
             backgroundcolor=box_colors[2],
             color='white', weight='roman', size='medium')
    fig.text(0.79-x_offset, 0.374-y_offset, 'x', color='white', backgroundcolor='silver',
             weight='roman', size='medium')
    fig.text(0.81-x_offset, 0.374-y_offset, ' Avg.', color='black', weight='roman',
             size='medium')
    plt.tight_layout()
    
    plt.savefig(path,format='eps')

    plt.show()

# %%
comb_dists = []
data = []
i=0
for q in q_dist:
    for m in m_dist:
        comb_dists.append(m+':'+q)
        for app in approach:
            data.append(df_list[i]['accuracy'])
            i+=1
print(comb_dists)
ylabel='Accuracy'
constraint='cost'
print(ylabel+' of query results when '+constraint+' is constrained')
boxplot(comb_dists,data,max_y=max(data[0]),
        ylabel='Accuracy',constraint='cost',
       path="image/accuacy_vs_approaches_constraint_cost.eps")

# %% [markdown]
# ## Pareto

# %%
def boxplot(com_dists,data,max_y=0,ylabel='Accuracy',constraint='Cost',size=14,path='',x_offset=0,y_offset=0):
    fig, ax1 = plt.subplots(figsize=(9, 6))
    fig.canvas.set_window_title('A Boxplot Example')
    fig.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)

    bp = ax1.boxplot(data, notch=0, sym='+', vert=1, whis=1.5)
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['fliers'], color='red', marker='+')

    # Add a horizontal grid to the plot, but make it very light in color
    # so we can use it for reading data values but not be distracting
    ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
                   alpha=0.5)

    ax1.set(
        axisbelow=True,  # Hide the grid behind plot objects
#         title=ylabel+' of query results when '+constraint+' is constrained',
        xlabel='Combinations (m_dist:q_dist)',
        ylabel=ylabel,
    )
    ax1.xaxis.get_label().set_fontsize(size)
    ax1.yaxis.get_label().set_fontsize(size)

    # Now fill the boxes with desired colors
    box_colors = ['#2694ab', '#e59572','#e16162']
    num_boxes = len(data)
    medians = np.empty(num_boxes)
    means = [np.mean(x) for x in data]
#     print(means)
    # pylab.scatter(range(1,len(data)+1), means)
    print('num_boxes',num_boxes)
    for i in range(num_boxes):
        box = bp['boxes'][i]
        box_x = []
        box_y = []
#         print(box.get_xdata())
#         print(box.get_ydata())
        for j in range(5):
            box_x.append(box.get_xdata()[j])
            box_y.append(box.get_ydata()[j])
        box_coords = np.column_stack([box_x, box_y])
        # Alternate between Dark Khaki and Royal Blue
        ax1.add_patch(Polygon(box_coords, facecolor=box_colors[i % 3]))
        # Now draw the median lines back over what we just filled in
        med = bp['medians'][i]
        median_x = []
        median_y = []
        for j in range(2):
            median_x.append(med.get_xdata()[j])
            median_y.append(med.get_ydata()[j])
            ax1.plot(median_x, median_y, 'k')
        medians[i] = median_y[0]
        # Finally, overplot the sample averages, with horizontal alignment
        # in the center of each box
        ax1.plot(np.average(med.get_xdata()), np.average(data[i]),
                 color='w', marker='X', markeredgecolor='k',markersize=10)

    # Set the axes ranges and axes labels
    ax1.set_xlim(0.5, num_boxes + 0.5)
    top = max_y * 1.1
    bottom = 0
    ax1.set_ylim(bottom, top)
    ax1.set_xticklabels(np.repeat(comb_dists, 3),
                        rotation=45, fontsize=size)
    ax1.tick_params(labelsize=size)

    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(num_boxes) + 1
    # upper_labels = [str(round(s, 2)) for s in medians]
    upper_labels = [str(round(s, 3)) for i,s in enumerate(means)]
    weights = ['bold', 'semibold','semibold']
    for tick, label in zip(range(num_boxes), ax1.get_xticklabels()):
        k = tick % 3
        ax1.text(pos[tick], .95, upper_labels[tick],
                 transform=ax1.get_xaxis_transform(),
                 horizontalalignment='center', size='medium',
                 weight=weights[k], color=box_colors[k])
    # Valid font size are xx-small, x-small, small, medium, large, x-large, xx-large, larger, smaller, None
    # Finally, add a basic legend
    fig.text(0.89-x_offset, 0.8-y_offset, 'Baseline',
             backgroundcolor=box_colors[0], color='white', weight='roman',
             size='medium')
    fig.text(0.89-x_offset, 0.761-y_offset, 'Optimizer',
             backgroundcolor=box_colors[1], color='white', weight='roman',
             size='medium')
    fig.text(0.89-x_offset, 0.717-y_offset, 'Order_Opt',
             backgroundcolor=box_colors[2],
             color='white', weight='roman', size='medium')
    fig.text(0.89-x_offset, 0.674-y_offset, 'x', color='white', backgroundcolor='silver',
             weight='roman', size='medium')
    fig.text(0.91-x_offset, 0.674-y_offset, ' Avg.', color='black', weight='roman',
             size='medium')
    plt.tight_layout()
    
    plt.savefig(path,format='eps')

    plt.show()

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer','order_opt']

comb_dists = []
data = []
i = 0
for q in q_dist:
    for m in m_dist:
        comb_dists.append(m+':'+q)
        for app in approach:
            data.append(df_list[i]['pareto_ratio'])
            i+=1
print(comb_dists)

boxplot(comb_dists,data,max_y=max([max(x) for x in data]),
        ylabel='Pareto ratio',constraint='cost', x_offset=0.06,
       path='image/pareto_vs_approaches_constraint_cost.eps')

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer']


comb_dists = []
data = []
i=0

for a,app in enumerate(approach):
    for i,m in enumerate(m_dist):
        for j,q in enumerate(q_dist):
            if app == 'baseline_pareto':
                app = 'baseline'
            comb_dists.append(app+'-'+m+':'+q)
            data.append(df_list[4*i+2*j+a][['#predicate','optimization_time']])
print(comb_dists)

# %%
import seaborn as sns
plt.rcParams['figure.dpi'] = 200
df = pd.DataFrame(columns=['#predicate','approach','optimization_time'])

for i,d in enumerate(data):
    d.loc[d['#predicate']==15,'#predicate']= 16
    d.loc[30-d['#predicate']<5,'#predicate'] = 32
    d['approach'] = [comb_dists[i]]*len(d)
    df = df.append(d,ignore_index=True)

    
# dd=pd.melt(df,id_vars=['#predicate'],value_vars=['Apple','Orange'],var_name='fruits')
g = sns.boxplot(x='#predicate',y='optimization_time',data=df,hue='approach')
# g.set_title("Runtime against #predicate in a query when constrained on cost",fontsize=8)
# plt.legend(bbox_to_anchor=(0.9, 0.8))
g.legend(loc='upper center', bbox_to_anchor=(0.45, 1.45),
          ncol=2, fancybox=True, shadow=True,prop={'size': 9})
g.set_yscale("log")
g.tick_params(labelsize=11)
g.xaxis.get_label().set_fontsize(11)
g.yaxis.get_label().set_fontsize(11)
plt.tight_layout()
plt.savefig('image/runtime_vs_approaches_constraint_cost.eps',format='eps')

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer']

comb_dists = []
data = []
i=0
for m in m_dist:
    for q in q_dist:
        comb_dists.append(m+':'+q)
        data.append(df_list[i*2+1][['#predicate','optimization_time']])
        i+=1
print(comb_dists)

# %%
plt.rcParams['figure.dpi'] = 200
df = pd.DataFrame(columns=['#predicate','optimizer','optimization_time'])

for i,d in enumerate(data):
    d.loc[d['#predicate']==15,'#predicate']= 16
    d.loc[30-d['#predicate']<5,'#predicate'] = 32
    d['optimizer'] = [comb_dists[i]]*len(d)
    df = df.append(d,ignore_index=True)

# dd=pd.melt(df,id_vars=['#predicate'],value_vars=['Apple','Orange'],var_name='fruits')
g = sns.boxplot(x='#predicate',y='optimization_time',data=df,hue='optimizer')
# g.set_title("Runtime against #predicate in a query when constrained on cost",fontsize=8)
g.legend(loc='upper center', bbox_to_anchor=(0.6, 0.2),
          ncol=2, fancybox=True, shadow=True,prop={'size': 9})
g.set_yscale("log")

g.tick_params(labelsize=11)
g.xaxis.get_label().set_fontsize(11)
g.yaxis.get_label().set_fontsize(11)
plt.tight_layout()
plt.savefig('image/runtime_vs_optimizers_constraint_cost.eps',format='eps')

# %%
q_dist = ['uniform']
m_dist = q_dist
approach = ['baseline_pareto','optimizer']

def load(m_dist,q_dist,approach):
    filepath = 'output/summary_cost_'+m_dist+'_'+q_dist+'_'+approach+'.csv'
    df = pd.read_csv(filepath,index_col=0)
#     print(df.head())
    return df[['#predicate','optimization_time']]

comb_dists = []
data = []
i=0
for m in m_dist:
    for q in q_dist:
        for app in approach:
            comb_dists.append(app)
            data.append(df_list[i][['#predicate','optimization_time']])
            i+=1
print(comb_dists)

plt.rcParams['figure.dpi'] = 200
df = pd.DataFrame(columns=['#predicate','approach','optimization_time'])

for i,d in enumerate(data):
    d.loc[d['#predicate']==15,'#predicate']= 16
    d.loc[30-d['#predicate']<5,'#predicate'] = 32
    d['approach'] = [comb_dists[i]]*len(d)
    df = df.append(d,ignore_index=True)
    
print(df.shape)
print(df.head())
    
# dd=pd.melt(df,id_vars=['#predicate'],value_vars=['Apple','Orange'],var_name='fruits')
g = sns.boxplot(x='#predicate',y='optimization_time',data=df,hue='approach')
g.set_title("Runtime against #predicate in a query when constrained on cost",fontsize=8)
g.set_yscale("log")

# %% [markdown]
# ## Constraint on accuracy, minmize cost

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer']


def load_accu(m_dist,q_dist,approach):
    filepath = 'output/summary_accuracy_'+m_dist+'_'+q_dist+'_'+approach+'.csv'
    df = pd.read_csv(filepath,index_col=0)
    print(df.shape)
#     print(df.head())
    return df

df_list = []
label_list = []
for q in q_dist:
    for m in m_dist:
        for app in approach:
            df_list.append(load_accu(m,q,app))
            label_list.append(app+'_'+m+'_'+q)
print(label_list)

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer','order_opt']


def load_cost(m_dist,q_dist,approach):
    filepath = 'output/summary_accuracy_'+m_dist+'_'+q_dist+'_'+approach+'.csv'
    if approach == 'order_opt':
        filepath = 'output/summary_order_accuracy_'+m_dist+'_'+q_dist+'_optimizer.csv'
    try:
        df = pd.read_csv(filepath,index_col=0)
    except Exception as e:
        filepath = 'output/summary_cost_'+m_dist+'_'+q_dist+'_'+approach+'_a=5.csv'
        df = pd.read_csv(filepath,index_col=0)
        
    print(df.shape)
#     print(df.head())
    return df

df_list = []
label_list = []
for q in q_dist:
    for m in m_dist:
        for app in approach:
            df_list.append(load_cost(m,q,app))
            if app == 'baseline_pareto':
                app = 'baseline'
            label_list.append(app+'_'+m+'_'+q)
print(label_list)

# %%
plt.rcParams['figure.dpi'] = 100
fig, ax = plt.subplots()

for i in range(len(df_list)):
    ax.scatter(df_list[i]['cost'], df_list[i]['accuracy'],label=label_list[i])

plt.ylabel('Accuracy')
plt.xlabel('Cost')
# plt.yscale('logit')
plt.legend()

# %%
def boxplot(com_dists,data,max_y=0,ylabel='Accuracy',constraint='Cost',size=14,path='',x_offset=0,y_offset=0):
    fig, ax1 = plt.subplots(figsize=(9, 6))
    fig.canvas.set_window_title('A Boxplot Example')
    fig.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)

    bp = ax1.boxplot(data, notch=0, sym='+', vert=1, whis=1.5)
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['fliers'], color='red', marker='+')

    # Add a horizontal grid to the plot, but make it very light in color
    # so we can use it for reading data values but not be distracting
    ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
                   alpha=0.5)

    ax1.set(
        axisbelow=True,  # Hide the grid behind plot objects
#         title=ylabel+' of query results when '+constraint+' is constrained',
        xlabel='Combinations (m_dist:q_dist)',
        ylabel=ylabel,
    )
    ax1.xaxis.get_label().set_fontsize(size)
    ax1.yaxis.get_label().set_fontsize(size)

    # Now fill the boxes with desired colors
    box_colors = ['#2694ab', '#e59572','#e16162']
    num_boxes = len(data)
    medians = np.empty(num_boxes)
    means = [np.mean(x) for x in data]
#     print(means)
    # pylab.scatter(range(1,len(data)+1), means)
    print('num_boxes',num_boxes)
    for i in range(num_boxes):
        box = bp['boxes'][i]
        box_x = []
        box_y = []
#         print(box.get_xdata())
#         print(box.get_ydata())
        for j in range(5):
            box_x.append(box.get_xdata()[j])
            box_y.append(box.get_ydata()[j])
        box_coords = np.column_stack([box_x, box_y])
        # Alternate between Dark Khaki and Royal Blue
        ax1.add_patch(Polygon(box_coords, facecolor=box_colors[i % 3]))
        # Now draw the median lines back over what we just filled in
        med = bp['medians'][i]
        median_x = []
        median_y = []
        for j in range(2):
            median_x.append(med.get_xdata()[j])
            median_y.append(med.get_ydata()[j])
            ax1.plot(median_x, median_y, 'k')
        medians[i] = median_y[0]
        # Finally, overplot the sample averages, with horizontal alignment
        # in the center of each box
        ax1.plot(np.average(med.get_xdata()), np.average(data[i]),
                 color='w', marker='X', markeredgecolor='k',markersize=10)

    # Set the axes ranges and axes labels
    ax1.set_xlim(0.5, num_boxes + 0.5)
    top = max_y * 0.2
    bottom = 0
    ax1.set_ylim(bottom, top)
    ax1.set_xticklabels(np.repeat(comb_dists, 3),
                        rotation=45, fontsize=size)
    ax1.tick_params(labelsize=size)

    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(num_boxes) + 1
    # upper_labels = [str(round(s, 2)) for s in medians]
    upper_labels = [str(round(s, 3)) for i,s in enumerate(means)]
    weights = ['bold', 'semibold','semibold']
    for tick, label in zip(range(num_boxes), ax1.get_xticklabels()):
        k = tick % 3
        ax1.text(pos[tick], .95, upper_labels[tick],
                 transform=ax1.get_xaxis_transform(),
                 horizontalalignment='center', size='medium',
                 weight=weights[k], color=box_colors[k])
    # Valid font size are xx-small, x-small, small, medium, large, x-large, xx-large, larger, smaller, None
    # Finally, add a basic legend
#     ax1.set_yscale('log')
    fig.text(0.79-x_offset, 0.5-y_offset, 'Baseline   ',
             backgroundcolor=box_colors[0], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.461-y_offset, 'Optimizer ',
             backgroundcolor=box_colors[1], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.417-y_offset, 'Order_Opt',
             backgroundcolor=box_colors[2],
             color='white', weight='roman', size='medium')
    fig.text(0.79-x_offset, 0.374-y_offset, 'x', color='white', backgroundcolor='silver',
             weight='roman', size='medium')
    fig.text(0.81-x_offset, 0.374-y_offset, ' Avg.', color='black', weight='roman',
             size='medium')
    plt.tight_layout()
    
    plt.savefig(path,format='eps')

    plt.show()

# %%
comb_dists = []
data = []
i=0
for q in q_dist:
    for m in m_dist:
        comb_dists.append(m+':'+q)
        for app in approach:
            data.append(df_list[i]['cost'])
            i+=1
print(comb_dists)

boxplot(comb_dists,data,max_y=max([max(x) for x in data]),
        ylabel='Cost',constraint='accuracy',
       path='image/cost_vs_approaches_constraint_accu.eps',
       y_offset=-0.2)

# %% [markdown]
# ## Pareto ratio

# %%
def boxplot(com_dists,data,max_y=0,ylabel='Accuracy',constraint='Cost',size=14,path='',x_offset=0,y_offset=0):
    fig, ax1 = plt.subplots(figsize=(9, 6))
    fig.canvas.set_window_title('A Boxplot Example')
    fig.subplots_adjust(left=0.075, right=0.95, top=0.9, bottom=0.25)

    bp = ax1.boxplot(data, notch=0, sym='+', vert=1, whis=1.5)
    plt.setp(bp['boxes'], color='black')
    plt.setp(bp['whiskers'], color='black')
    plt.setp(bp['fliers'], color='red', marker='+')

    # Add a horizontal grid to the plot, but make it very light in color
    # so we can use it for reading data values but not be distracting
    ax1.yaxis.grid(True, linestyle='-', which='major', color='lightgrey',
                   alpha=0.5)

    ax1.set(
        axisbelow=True,  # Hide the grid behind plot objects
#         title=ylabel+' of query results when '+constraint+' is constrained',
        xlabel='Combinations (m_dist:q_dist)',
        ylabel=ylabel,
    )
    ax1.xaxis.get_label().set_fontsize(size)
    ax1.yaxis.get_label().set_fontsize(size)

    # Now fill the boxes with desired colors
    box_colors = ['#2694ab', '#e59572','#e16162']
    num_boxes = len(data)
    medians = np.empty(num_boxes)
    means = [np.mean(x) for x in data]
#     print(means)
    # pylab.scatter(range(1,len(data)+1), means)
    print('num_boxes',num_boxes)
    for i in range(num_boxes):
        box = bp['boxes'][i]
        box_x = []
        box_y = []
#         print(box.get_xdata())
#         print(box.get_ydata())
        for j in range(5):
            box_x.append(box.get_xdata()[j])
            box_y.append(box.get_ydata()[j])
        box_coords = np.column_stack([box_x, box_y])
        # Alternate between Dark Khaki and Royal Blue
        ax1.add_patch(Polygon(box_coords, facecolor=box_colors[i % 3]))
        # Now draw the median lines back over what we just filled in
        med = bp['medians'][i]
        median_x = []
        median_y = []
        for j in range(2):
            median_x.append(med.get_xdata()[j])
            median_y.append(med.get_ydata()[j])
            ax1.plot(median_x, median_y, 'k')
        medians[i] = median_y[0]
        # Finally, overplot the sample averages, with horizontal alignment
        # in the center of each box
        ax1.plot(np.average(med.get_xdata()), np.average(data[i]),
                 color='w', marker='X', markeredgecolor='k',markersize=10)

    # Set the axes ranges and axes labels
    ax1.set_xlim(0.5, num_boxes + 0.5)
    top = max_y * 1.1
    bottom = 0
    ax1.set_ylim(bottom, top)
    ax1.set_xticklabels(np.repeat(comb_dists, 3),
                        rotation=45, fontsize=size)
    ax1.tick_params(labelsize=size)

    # Due to the Y-axis scale being different across samples, it can be
    # hard to compare differences in medians across the samples. Add upper
    # X-axis tick labels with the sample medians to aid in comparison
    # (just use two decimal places of precision)
    pos = np.arange(num_boxes) + 1
    # upper_labels = [str(round(s, 2)) for s in medians]
    upper_labels = [str(round(s, 3)) for i,s in enumerate(means)]
    weights = ['bold', 'semibold','semibold']
    for tick, label in zip(range(num_boxes), ax1.get_xticklabels()):
        k = tick % 3
        ax1.text(pos[tick], .95, upper_labels[tick],
                 transform=ax1.get_xaxis_transform(),
                 horizontalalignment='center', size='medium',
                 weight=weights[k], color=box_colors[k])
    # Valid font size are xx-small, x-small, small, medium, large, x-large, xx-large, larger, smaller, None
    # Finally, add a basic legend
    fig.text(0.79-x_offset, 0.5-y_offset, 'Baseline',
             backgroundcolor=box_colors[0], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.461-y_offset, 'Optimizer',
             backgroundcolor=box_colors[1], color='white', weight='roman',
             size='medium')
    fig.text(0.79-x_offset, 0.417-y_offset, 'Order_Opt',
             backgroundcolor=box_colors[2],
             color='white', weight='roman', size='medium')
    fig.text(0.79-x_offset, 0.374-y_offset, 'x', color='white', backgroundcolor='silver',
             weight='roman', size='medium')
    fig.text(0.81-x_offset, 0.374-y_offset, ' Avg.', color='black', weight='roman',
             size='medium')
    plt.tight_layout()
    
    plt.savefig(path,format='eps')

    plt.show()

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist
approach = ['baseline_pareto','optimizer','order_opt']


comb_dists = []
data = []
i=0
for q in q_dist:
    for m in m_dist:
        comb_dists.append(m+':'+q)
        for app in approach:
            data.append(df_list[i]['pareto_ratio'])
            i+=1
print(comb_dists)

boxplot(comb_dists,data,max_y=max([max(x) for x in data]),
        ylabel='Pareto ratio',constraint='cost',
        path='image/pareto_vs_approaches_constraint_cost.eps',
       x_offset=0.07)

# %% [markdown]
# ### Runtime

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist

def load(m_dist,q_dist,approach):
    filepath = 'repository/run_summary_accuracy_'+m_dist+'_'+q_dist+'_'+approach+'.csv'
    df = pd.read_csv(filepath,index_col=0)
#     print(df.head())
    return df[['#predicate','optimization_time']]

comb_dists = []
data = []
i=0
for m in m_dist:
    for q in q_dist:
        comb_dists.append(m+':'+q)
        data.append(df_list[i*2+1][['#predicate','optimization_time']])
        i+=1
print(comb_dists)

# %%
plt.rcParams['figure.dpi'] = 200
df = pd.DataFrame(columns=['#predicate','optimizer','optimization_time'])

for i,d in enumerate(data):
    d.loc[d['#predicate']==15,'#predicate']= 16
    d.loc[30-d['#predicate']<5,'#predicate'] = 32
    d['optimizer'] = [comb_dists[i]]*len(d)
    df = df.append(d,ignore_index=True)

# dd=pd.melt(df,id_vars=['#predicate'],value_vars=['Apple','Orange'],var_name='fruits')
g = sns.boxplot(x='#predicate',y='optimization_time',data=df,hue='optimizer')
# g.set_title("Runtime against #predicate in a query when constrained on accuarcy",fontsize=8)
g.set_yscale("log")
g.legend(loc='upper center', bbox_to_anchor=(0.6, 0.2),
          ncol=2, fancybox=True, shadow=True,prop={'size': 9})
g.set_yscale("log")

g.tick_params(labelsize=11)
g.xaxis.get_label().set_fontsize(11)
g.yaxis.get_label().set_fontsize(11)
plt.tight_layout()
plt.savefig('image/runtime_vs_optimizers_constraint_accu.eps',format='eps')

# %%
fig, ax = plt.subplots()
ax.scatter(x_optimizer,_optimizer['pareto_ratio'],label='optimizer')
ax.scatter(x_mix_optimizer,mix_optimizer['pareto_ratio'],label='optimizer-mix')
ax.scatter(x_uni_mix_optimizer,uni_mix_optimizer['pareto_ratio'],label='optimizer-uni-mix')
ax.scatter(x_pow_optimizer,pow_optimizer['pareto_ratio'],label='optimizer-pow')

# rectangular box plot
bplot1 = ax.boxplot([_optimizer[_optimizer['#predicate']==k]['pareto_ratio'] for k in [2,4,8,16,32]],
                     showfliers=False,
                     vert=True,  # vertical box alignment
                     labels=range(5)) 
c1 = "blue"
for item in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
    plt.setp(bplot1[item], color=c1)

bplot1 = ax.boxplot([mix_optimizer[mix_optimizer['#predicate']==k]['pareto_ratio'] for k in [2,4,8,16,32]],
                     showfliers=False,
                     vert=True,  # vertical box alignment
                     labels=range(5)) 
c2 = "orange"
for item in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
    plt.setp(bplot1[item], color=c2)
    
# bplot1 = ax.boxplot([x_uni_mix_optimizer[x_uni_mix_optimizer['#predicate']==k]['pareto_ratio'] for k in [2,4,8,16,32]],
#                      showfliers=False,
#                      vert=True,  # vertical box alignment
#                      labels=range(5)) 

# c2 = "orange"
# for item in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
#     plt.setp(bplot1[item], color=c2)
    
plt.xticks(range(1,6),key)
plt.ylabel('Pareto ratio')
plt.xlabel('#predicate')
plt.legend()

# %%
def boxplot(data,query_range):
    box_colors = ['darkkhaki', 'royalblue']
    fig, ax = plt.subplots()
    ax.set_title('Pareto Ratio')
    bp = ax.boxplot(data)
    plt.xticks(range(1,len(query_range)+1), query_range)
    plt.xlabel("#queries")
    plt.ylabel("Pareto ratio")
    plt.show()

# %% [markdown]
# ## Runtime

# %%
fig, ax = plt.subplots()
ax.scatter(x_baseline, _baseline['runtime'],label='baseline')
ax.scatter(x_optimizer,_optimizer['pareto_ratio'],c='orange',label='optimizer')
# rectangular box plot
bplot1 = ax.boxplot([_baseline[_baseline['#predicate']==k]['pareto_ratio'] for k in key],
                     notch=True,
                     vert=True,  # vertical box alignment
                     showfliers=False,
                     labels=range(5))  # will be used to label x-ticks
c1 = "blue"
for item in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
    plt.setp(bplot1[item], color=c1)

bplot1 = ax.boxplot([_optimizer[_optimizer['#predicate']==k]['pareto_ratio'] for k in key],
                     showfliers=False,
                     vert=True,  # vertical box alignment
                     labels=range(5)) 
c2 = "orange"
for item in ['boxes', 'whiskers', 'fliers', 'medians', 'caps']:
    plt.setp(bplot1[item], color=c2)
plt.xticks(range(1,6),key)
plt.ylabel('Pareto ratio')
plt.xlabel('#predicate')
plt.legend()

# %% [markdown]
# ## YOLOV3 converted performance

# %%
import matplotlib.pyplot as plt
from matplotlib.patches import Polygon
from pandas.plotting import andrews_curves
import pylab
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
q_dist = ['uniform','power_law']
m_dist = q_dist

filepath = '/Users/lizy/my_doc/PhD/Code/Project_Boolean_Query_Plan/repository/model_stats_f1.csv'
df_convert =  pd.read_csv(filepath,index_col=0)

# base_cost = [165,1560]
# cost = df_convert['cost']
# cost = [round(16*(c-base_cost[0])+base_cost[0]) if c < 1000 else round(16*(c-base_cost[1])+base_cost[1]) for c in cost]
# df_convert['cost'] = cost
# df_convert.to_csv('/Users/lizy/my_doc/PhD/Code/Project_Boolean_ML_Optimization/yolov3/convert/model_stats_new.csv')

columns = df_convert.columns
classes = [c for c in columns if c != 'cost']

df_accu = df_convert.loc[:,classes]
cost = df_convert['cost']
print(list(cost))
df_accu.head()
# Out:
# [76.0, 26.0, 44.0, 37.0, 26.0, 83.0, 37.0, 31.0, 52.0, 48.0, 78.0, 39.0, 43.0, 75.0, 78.0, 36.0, 52.0, 50.0, 29.0, 40.0, 29.0, 28.0, 48.0, 80.0, 59.0, 21.0, 67.0, 33.0, 47.0, 72.0, 60.0, 61.0, 53.0, 44.0, 44.0, 49.0, 34.0, 27.0, 35.0, 71.0, 23.0, 48.0, 56.0, 45.0, 24.0, 87.0, 66.0, 66.0, 58.0, 34.0, 32.0, 61.0, 34.0, 87.0, 45.0, 63.0, 59.0, 17.0, 48.0, 26.0, 55.0, 53.0, 65.0, 43.0, 18.0, 51.0, 60.0, 57.0, 25.0, 35.0, 34.0, 37.0, 33.0, 75.0, 42.0, 50.0, 72.0, 61.0, 52.0, 67.0, 44.0, 38.0, 80.0, 37.0, 60.0, 32.0, 41.0, 79.0, 65.0, 69.0, 78.0, 40.0, 43.0, 64.0, 42.0, 58.0, 68.0, 62.0, 32.0, 43.0, 31.0, 39.0, 47.0, 45.0, 66.0, 85.0, 42.0, 49.0, 82.0, 70.0, 68.0, 40.0, 71.0, 60.0, 60.0, 53.0, 75.0, 37.0, 45.0, 58.0, 67.0, 54.0, 66.0, 37.0, 64.0]
#            snowboard  carrot  keyboard  cell phone  sports ball  clock   bus  \
# model_64        0.31    0.44      0.45        0.43         0.50   0.53  0.57
# model_45        0.39    0.41       NaN         NaN          NaN   0.61  0.60
# model_133        NaN     NaN      0.68         NaN         0.74    NaN   NaN
# model_132       0.46    0.40       NaN         NaN          NaN   0.66  0.74
# model_32         NaN    0.46       NaN         NaN          NaN   0.68   NaN
#
#            person  surfboard  refrigerator  ...  tennis racket  toaster  \
# model_64     0.68       0.53          0.50  ...            NaN      NaN
# model_45      NaN        NaN           NaN  ...            NaN      NaN
# model_133     NaN       0.73          0.63  ...            NaN      NaN
# model_132    0.73       0.67           NaN  ...            0.7     0.24
# model_32     0.73       0.64           NaN  ...            NaN     0.18
#
#            zebra  fire hydrant  motorcycle   cat  potted plant  wine glass  \
# model_64     NaN           NaN         NaN   NaN           NaN         NaN
# model_45     NaN           NaN         NaN   NaN           NaN         NaN
# model_133    NaN           NaN         NaN   NaN           NaN         NaN
# model_132   0.74           NaN         NaN   NaN           NaN         NaN
# model_32    0.78          0.63        0.69  0.77          0.58         NaN
#
#            baseball bat  truck
# model_64            NaN    NaN
# model_45            NaN    NaN
# model_133           NaN    NaN
# model_132           NaN    NaN
# model_32            NaN    NaN
#
# [5 rows x 80 columns]

# %%
df_accu.shape
# Out:
# (125, 80)

# %%
df_class = df_accu.notnull().sum()
df_class = df_class.sort_values()
print(df_class.head())
# Out:
# horse       32
# airplane    33
# apple       33
# remote      34
# cake        34
# dtype: int64

# %%
plt.rcParams['figure.dpi'] = 200

fig, ax = plt.subplots()
plt.plot(df_class)
plt.title('Task coverage')
plt.xlabel('Class')
plt.ylabel('Frequency')
ax.set_xticklabels(labels=df_class.index,rotation=90, fontsize=4.5)
plt.show()

# %%
df_accu['cost'] = cost
print(df_accu.shape)
df_accu.head()
# Out:
# (125, 81)
#            snowboard  carrot  keyboard  cell phone  sports ball  clock   bus  \
# model_64        0.31    0.44      0.45        0.43         0.50   0.53  0.57
# model_45        0.39    0.41       NaN         NaN          NaN   0.61  0.60
# model_133        NaN     NaN      0.68         NaN         0.74    NaN   NaN
# model_132       0.46    0.40       NaN         NaN          NaN   0.66  0.74
# model_32         NaN    0.46       NaN         NaN          NaN   0.68   NaN
#
#            person  surfboard  refrigerator  ...  toaster  zebra  fire hydrant  \
# model_64     0.68       0.53          0.50  ...      NaN    NaN           NaN
# model_45      NaN        NaN           NaN  ...      NaN    NaN           NaN
# model_133     NaN       0.73          0.63  ...      NaN    NaN           NaN
# model_132    0.73       0.67           NaN  ...     0.24   0.74           NaN
# model_32     0.73       0.64           NaN  ...     0.18   0.78          0.63
#
#            motorcycle   cat  potted plant  wine glass  baseball bat  truck  \
# model_64          NaN   NaN           NaN         NaN           NaN    NaN
# model_45          NaN   NaN           NaN         NaN           NaN    NaN
# model_133         NaN   NaN           NaN         NaN           NaN    NaN
# model_132         NaN   NaN           NaN         NaN           NaN    NaN
# model_32         0.69  0.77          0.58         NaN           NaN    NaN
#
#            cost
# model_64   76.0
# model_45   26.0
# model_133  44.0
# model_132  37.0
# model_32   26.0
#
# [5 rows x 81 columns]

# %%
# df_accu.to_csv(filepath)

# %%
plt.rcParams['figure.dpi'] = 200

def plot(df,T):
    fig, ax = plt.subplots()
    for i, t in enumerate(T):
        data = df.loc[:,[t,'cost']]
        data.dropna(inplace=True)
        ax.scatter(df['cost'], df[t])
        
    plt.title('Summary of model repository')
    plt.xlabel('Cost')
    plt.ylabel('f1 score')
    plt.show()
    
# print(classes)
# plot(df_convert,list(classes))
plot(df_accu,list(classes))

# %%
classes
# Out:
# ['snowboard',
#  'carrot',
#  'keyboard',
#  'cell phone',
#  'sports ball',
#  'clock',
#  'bus',
#  'person',
#  'surfboard',
#  'refrigerator',
#  'knife',
#  'backpack',
#  'dog',
#  'cup',
#  'bear',
#  'tie',
#  'banana',
#  'baseball glove',
#  'tv',
#  'microwave',
#  'bowl',
#  'fork',
#  'couch',
#  'umbrella',
#  'kite',
#  'train',
#  'remote',
#  'oven',
#  'bicycle',
#  'skis',
#  'orange',
#  'sink',
#  'sheep',
#  'spoon',
#  'traffic light',
#  'airplane',
#  'teddy bear',
#  'laptop',
#  'giraffe',
#  'bed',
#  'mouse',
#  'hair dryer',
#  'donut',
#  'chair',
#  'boat',
#  'cake',
#  'scissors',
#  'stop sign',
#  'toilet',
#  'book',
#  'bench',
#  'broccoli',
#  'elephant',
#  'frisbee',
#  'apple',
#  'toothbrush',
#  'parking meter',
#  'bottle',
#  'cow',
#  'pizza',
#  'car',
#  'dining table',
#  'sandwich',
#  'handbag',
#  'hot dog',
#  'horse',
#  'bird',
#  'suitcase',
#  'skateboard',
#  'vase',
#  'tennis racket',
#  'toaster',
#  'zebra',
#  'fire hydrant',
#  'motorcycle',
#  'cat',
#  'potted plant',
#  'wine glass',
#  'baseball bat',
#  'truck']

# %%
plt.rcParams['figure.dpi'] = 200

def plot(df,T):
    fig, ax = plt.subplots()
    for i, t in enumerate(T):
        print(t)
        data = df.loc[:,[t,'cost']]
        data.dropna(inplace=True)
        ax.scatter(df['cost'], df[t],label=t)
        
    plt.title('Summary of class')
    plt.xlabel('Cost')
    plt.ylabel('mAP')
    plt.legend()
    plt.show()
    
# print(classes)

plot(df_convert,['person','bus','car'])
# Out:
# person
# bus
# car
