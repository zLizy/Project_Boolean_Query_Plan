# %%
import matplotlib.pyplot as plt
from pandas.plotting import andrews_curves
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Model repository
# ### Sample distribution

# %%
# Load model repository

def load():
#     filepath = 'repository/model_repository_'+str(M)+'_'+str(N)+'_'+flag+'.csv'
    filepath = 'repository/model_stats_f1.csv'
    df = pd.read_csv(filepath,index_col=0)
    print(df.head())
    return df

df = load()
# Out:
#            snowboard  carrot  keyboard  cell phone  sports ball  clock   bus  \
# model_64        0.31    0.44      0.45        0.43         0.50   0.53  0.57
# model_45        0.39    0.41       NaN         NaN          NaN   0.61  0.60
# model_133        NaN     NaN      0.68         NaN         0.74    NaN   NaN
# model_132       0.46    0.40       NaN         NaN          NaN   0.66  0.74
# model_32         NaN    0.46       NaN         NaN          NaN   0.68   NaN
#
#            person  surfboard  refrigerator  ...  tennis racket  toaster  \
# model_64     0.68       0.53          0.50  ...            NaN      NaN
# model_45      NaN        NaN           NaN  ...            NaN      NaN
# model_133     NaN       0.73          0.63  ...            NaN      NaN
# model_132    0.73       0.67           NaN  ...            0.7     0.24
# model_32     0.73       0.64           NaN  ...            NaN     0.18
#
#            zebra  fire hydrant  motorcycle   cat  potted plant  wine glass  \
# model_64     NaN           NaN         NaN   NaN           NaN         NaN
# model_45     NaN           NaN         NaN   NaN           NaN         NaN
# model_133    NaN           NaN         NaN   NaN           NaN         NaN
# model_132   0.74           NaN         NaN   NaN           NaN         NaN
# model_32    0.78          0.63        0.69  0.77          0.58         NaN
#
#            baseball bat  truck
# model_64            NaN    NaN
# model_45            NaN    NaN
# model_133           NaN    NaN
# model_132           NaN    NaN
# model_32            NaN    NaN
#
# [5 rows x 81 columns]

# %% [markdown]
# ### General distribution

# %%
from pandas.plotting import scatter_matrix
plt.rcParams['figure.dpi'] = 200

def scatter(df,legend=False):
    
    columns = [c for c in df.columns if c!='cost']
    print(columns[:4])
    fig, ax = plt.subplots()
    for c in columns:
        ax.scatter(df['cost'], df[c],label=c)
    plt.xlabel("Cost")
    plt.ylabel('Accuracy')
    if legend:
        ax.legend()
    plt.show()

# scatter(df_median)
scatter(df)
scatter(df[['person','car','truck','cost']],legend=True)
# Out:
# ['snowboard', 'carrot', 'keyboard', 'cell phone']
# ['person', 'car', 'truck']

# %%
import scipy.stats as stats
import seaborn as sns
sns.set_style("white")

def scatter_hist(df,path):
    fig, ax1 = plt.subplots(figsize=(4, 4))
    scatter_axes = plt.subplot2grid((3, 2), (1, 0), rowspan=2, colspan=2)
    x_hist_axes = plt.subplot2grid((3, 2), (0, 0), colspan=2,sharex=scatter_axes)
#     y_hist_axes = plt.subplot2grid((3, 3), (1, 2), rowspan=2,sharey=scatter_axes)

    cost = list(df['cost'])
    print(cost)
    # scatter_axes.plot(x, y, '.')
    columns = [c for c in df.columns if c!='cost']
    for c in columns:
        scatter_axes.plot(cost, df[c], '.')
        #y_hist_axes.hist(df[c], orientation='horizontal',range=(0,1))
#         sns.distplot(list(df[c]),ax = y_hist_axes,vertical=True,hist = False,kde_kws = {'linewidth': 1})#, kde = True,
    
#     x_hist_axes.hist(cost)
    sns.distplot(cost,ax = x_hist_axes,hist = True,kde_kws = {'linewidth': 2})#, kde = True,

    
    scatter_axes.set_ylabel('Accuracy')
    scatter_axes.set_xlabel('Cost')
#     scatter_axes.set_xlim([0, 500])
    
    plt.tight_layout()
    
    plt.savefig(path,format='eps')
    plt.show()

scatter_hist(df,path='image/model_repository.eps')
# scatter_hist(df_max)
# Out:
# [76.0, 26.0, 44.0, 37.0, 26.0, 83.0, 37.0, 31.0, 52.0, 48.0, 78.0, 39.0, 43.0, 75.0, 78.0, 36.0, 52.0, 50.0, 29.0, 40.0, 29.0, 28.0, 48.0, 80.0, 59.0, 21.0, 67.0, 33.0, 47.0, 72.0, 60.0, 61.0, 53.0, 44.0, 44.0, 49.0, 34.0, 27.0, 35.0, 71.0, 23.0, 48.0, 56.0, 45.0, 24.0, 87.0, 66.0, 66.0, 58.0, 34.0, 32.0, 61.0, 34.0, 87.0, 45.0, 63.0, 59.0, 17.0, 48.0, 26.0, 55.0, 53.0, 65.0, 43.0, 18.0, 51.0, 60.0, 57.0, 25.0, 35.0, 34.0, 37.0, 33.0, 75.0, 42.0, 50.0, 72.0, 61.0, 52.0, 67.0, 44.0, 38.0, 80.0, 37.0, 60.0, 32.0, 41.0, 79.0, 65.0, 69.0, 78.0, 40.0, 43.0, 64.0, 42.0, 58.0, 68.0, 62.0, 32.0, 43.0, 31.0, 39.0, 47.0, 45.0, 66.0, 85.0, 42.0, 49.0, 82.0, 70.0, 68.0, 40.0, 71.0, 60.0, 60.0, 53.0, 75.0, 37.0, 45.0, 58.0, 67.0, 54.0, 66.0, 37.0, 64.0]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
import scipy.stats as stats
import seaborn as sns
sns.set_style("white")

def scatter_hist(df,path):
    figsize=(8, 6)
    scatter_axes = plt.subplot2grid((3, 3), (1, 0), rowspan=2, colspan=2)
    x_hist_axes = plt.subplot2grid((3, 3), (0, 0), colspan=2,
                                   sharex=scatter_axes)
    y_hist_axes = plt.subplot2grid((3, 3), (1, 2), rowspan=2,
                                   sharey=scatter_axes)

    cost = list(df['cost'])
    print(cost)
    # scatter_axes.plot(x, y, '.')
    columns = [c for c in df.columns if c!='cost'][::6]
    marker=['.',',','o','v','1','3','8']*3
    for i,c in enumerate(columns):
        scatter_axes.scatter(cost, df[c], marker=marker[i],s=20,label=c)
        #y_hist_axes.hist(df[c], orientation='horizontal',range=(0,1))
        sns.distplot(list(df[c]),ax = y_hist_axes,vertical=True,hist = False,kde_kws = {'linewidth': 1})#, kde = True,
    
#     x_hist_axes.hist(cost)
    sns.distplot(cost,ax = x_hist_axes,hist = True,kde_kws = {'linewidth': 2})#, kde = True,

    
    scatter_axes.set_ylabel('Accuracy')
    scatter_axes.set_xlabel('Cost')
    scatter_axes.set_xlim([10, 90])
    scatter_axes.set_ylim([0.1, 1])
#     scatter_axes.legend()
    plt.tight_layout()
    plt.savefig(path,format='eps')
    plt.show()

scatter_hist(df,path='image/model_repository_complete.eps')
# scatter_hist(df_max)
# Out:
# [76.0, 26.0, 44.0, 37.0, 26.0, 83.0, 37.0, 31.0, 52.0, 48.0, 78.0, 39.0, 43.0, 75.0, 78.0, 36.0, 52.0, 50.0, 29.0, 40.0, 29.0, 28.0, 48.0, 80.0, 59.0, 21.0, 67.0, 33.0, 47.0, 72.0, 60.0, 61.0, 53.0, 44.0, 44.0, 49.0, 34.0, 27.0, 35.0, 71.0, 23.0, 48.0, 56.0, 45.0, 24.0, 87.0, 66.0, 66.0, 58.0, 34.0, 32.0, 61.0, 34.0, 87.0, 45.0, 63.0, 59.0, 17.0, 48.0, 26.0, 55.0, 53.0, 65.0, 43.0, 18.0, 51.0, 60.0, 57.0, 25.0, 35.0, 34.0, 37.0, 33.0, 75.0, 42.0, 50.0, 72.0, 61.0, 52.0, 67.0, 44.0, 38.0, 80.0, 37.0, 60.0, 32.0, 41.0, 79.0, 65.0, 69.0, 78.0, 40.0, 43.0, 64.0, 42.0, 58.0, 68.0, 62.0, 32.0, 43.0, 31.0, 39.0, 47.0, 45.0, 66.0, 85.0, 42.0, 49.0, 82.0, 70.0, 68.0, 40.0, 71.0, 60.0, 60.0, 53.0, 75.0, 37.0, 45.0, 58.0, 67.0, 54.0, 66.0, 37.0, 64.0]
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %% [markdown]
# ## Task coverage

# %%
df.head()
# Out:
#            snowboard  carrot  keyboard  cell phone  sports ball  clock   bus  \
# model_64        0.31    0.44      0.45        0.43         0.50   0.53  0.57
# model_45        0.39    0.41       NaN         NaN          NaN   0.61  0.60
# model_133        NaN     NaN      0.68         NaN         0.74    NaN   NaN
# model_132       0.46    0.40       NaN         NaN          NaN   0.66  0.74
# model_32         NaN    0.46       NaN         NaN          NaN   0.68   NaN
#
#            person  surfboard  refrigerator  ...  tennis racket  toaster  \
# model_64     0.68       0.53          0.50  ...            NaN      NaN
# model_45      NaN        NaN           NaN  ...            NaN      NaN
# model_133     NaN       0.73          0.63  ...            NaN      NaN
# model_132    0.73       0.67           NaN  ...            0.7     0.24
# model_32     0.73       0.64           NaN  ...            NaN     0.18
#
#            zebra  fire hydrant  motorcycle   cat  potted plant  wine glass  \
# model_64     NaN           NaN         NaN   NaN           NaN         NaN
# model_45     NaN           NaN         NaN   NaN           NaN         NaN
# model_133    NaN           NaN         NaN   NaN           NaN         NaN
# model_132   0.74           NaN         NaN   NaN           NaN         NaN
# model_32    0.78          0.63        0.69  0.77          0.58         NaN
#
#            baseball bat  truck
# model_64            NaN    NaN
# model_45            NaN    NaN
# model_133           NaN    NaN
# model_132           NaN    NaN
# model_32            NaN    NaN
#
# [5 rows x 81 columns]

# %%
columns = [c for c in df.columns if c != 'cost']
df_accu = df[columns]
task_count = df_accu.notna().sum(axis=0).sort_values()
print(task_count)
# Out:
# horse            32
# airplane         33
# apple            33
# remote           34
# cake             34
#                  ..
# hot dog          52
# snowboard        52
# banana           53
# sports ball      53
# tennis racket    55
# Length: 80, dtype: int64

# %%
plt.rcParams['figure.dpi'] = 200
fig, ax = plt.subplots(figsize=(7, 5))
width=0.8
x = range(len(task_count))
rects1 = ax.bar(x, task_count.values, width)
ax.set_xticks(x)
ax.set_xticklabels(task_count.index,rotation=90,fontsize=5)
ax.set_xlabel('Class')
ax.set_ylabel('Frequency')
# ax.set_yscale('log')
plt.show()

# %% [markdown]
# ### Distribution on the number of model assinments to each task

# %%
columns = [c for c in df.columns if c != 'cost']
df_accu = df[columns]
count_task = df_accu.count()
count_task.head()
# Out:
# sports ball    31
# spoon          22
# dog            25
# snowboard      29
# bear           29
# dtype: int64

# %%
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
n_bins = 10
# We can set the number of bins with the `bins` kwarg
axs[0].hist(count_task, bins=n_bins)
# Out:
# (array([ 2.,  3., 14., 11., 13., 19.,  7.,  6.,  2.,  3.]),
#  array([17. , 19.3, 21.6, 23.9, 26.2, 28.5, 30.8, 33.1, 35.4, 37.7, 40. ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ### Distribution of model capability

# %%
count_m = df_accu.iloc[:,:-1].T.count()
count_m.head()
# Out:
# model_64     29
# model_175     9
# model_45      6
# model_159     2
# model_154     1
# dtype: int64

# %%
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
n_bins = 5
# We can set the number of bins with the `bins` kwarg
axs[0].hist(count_m, bins=n_bins)
# Out:
# (array([120.,  49.,  22.,   5.,   4.]),
#  array([ 1. , 10.2, 19.4, 28.6, 37.8, 47. ]),
#  <BarContainer object of 5 artists>)

# %%
fig, axs = plt.subplots(1, 2, sharey=True, tight_layout=True)
axs[0].hist(df_median['cost'])
axs[1].hist(df_max['cost'])

fig, ax = plt.subplots()
ax.hist2d(list(df_median['cost'])[:-1],df_max['cost'])
plt.show()

# %% [markdown]
# ### Pareto Ratio

# %%
path = 'repository/model_pareto_summary.csv'
df_summary = pd.read_csv(path,index_col=0)
query_range = [50,100,150,200]

# %%
def getData(df,M,N,flag,query_range):
    df_summary = df.loc[df['M']==M]
    df_summary = df_summary.loc[df['N']==N]
    df_summary = df_summary.loc[df_summary['flag']==flag]
    print(df_summary.head())
    data = [df_summary.loc[df_summary['#query'] == n,'ratio'] for n in query_range]
    return data

# %%
def boxplot(data,M,N,query_range):
    box_colors = ['darkkhaki', 'royalblue']
    fig, ax = plt.subplots()
    ax.set_title('Pareto Ratio with Different Number of Queries (M='+str(M)+',N='+str(N)+')')
    bp = ax.boxplot(data)
    plt.xticks(range(1,len(query_range)+1), query_range)
    plt.xlabel("#queries")
    plt.ylabel("Pareto ratio")
    plt.show()

# %%
M=100
N=40
flag='median'
data = getData(df_summary,M,N,flag,query_range)
data_max = getData(df_summary,M,N,'max',query_range)
print(data)
boxplot(data,M,N,query_range)
boxplot(data_max,M,N,query_range)
# Out:
#      M   N  #query  #predicates  #pareto   ratio    flag
# 0  100  40      50          188      186  0.9894  median
# 1  100  40      50          204      194  0.9510  median
# 2  100  40      50          199      195  0.9799  median
# 3  100  40      50          234      221  0.9444  median
# 4  100  40      50          239      228  0.9540  median
#      M   N  #query  #predicates  #pareto   ratio flag
# 5  100  40      50          168      165  0.9821  max
# 6  100  40      50          184      182  0.9891  max
# 7  100  40      50          216      208  0.9630  max
# 8  100  40      50          194      184  0.9485  max
# 9  100  40      50          212      207  0.9764  max
# [0    0.9894
# 1    0.9510
# 2    0.9799
# 3    0.9444
# 4    0.9540
# Name: ratio, dtype: float64, 10    0.9556
# 11    0.9607
# 12    0.9787
# 13    0.9582
# Name: ratio, dtype: float64, 19    0.9664
# 20    0.9512
# 21    0.9470
# 22    0.9694
# 23    0.9459
# Name: ratio, dtype: float64, 29    0.9637
# 30    0.9604
# 31    0.9742
# 32    0.9706
# 33    0.9558
# Name: ratio, dtype: float64]

# %% [markdown]
# ## Check task with non-pareto model

# %%
path = 'repository/non_pareto_query_summary.csv'
df_non_pareto = pd.read_csv(path,index_col=0)
df_non_pareto.head()
# Out:
#                                                query                predicate  \
# 0  (T9 & T21) | T25 & T6 | (T19 | T2) | T10 | T22...                  T10.M33
# 1                              T12 | T38 | T34 | T14                  T14.M35
# 2         (T17 & T30) & (T7 & T33) & T19 & T29 & T26          T19.M50|T17.M50
# 3                (T18 | T38 | T35 | T32 & T25 & T11)                  T35.M91
# 4  T28 & (T5 | T18) & (T28 | T27 & T24) & T32 & (...  T16.M51|T34.M84|T33.M84
#
#    flag
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
df_np_median = df_non_pareto.loc[df_non_pareto['flag']==0]
df_np_max = df_non_pareto.loc[df_non_pareto['flag']==1]

# %%
# get pareto
def TwoDimensionsPD(data):
    data.dropna(inplace=True)
    map_dict = {}
    columns=data.columns
    sorted_data = data.sort_values(by='cost')
    index = list(sorted_data.index)

    map_dict[index[0]] = 1
    cutt_off = sorted_data[columns[0]][0]
    for i in range(1, len(sorted_data)):
        if sorted_data[columns[0]][i] > cutt_off:
            cutt_off = sorted_data[columns[0]][i]
            map_dict[index[i]] = 1
    return map_dict

# %%
for i in range(5):
    predicates = df_np_median.loc[i,'predicate']
    query = df_np_median.loc[i,'query']
    predicate = predicates.split('|')
    for p in predicate:
        t, m = p.split('.')
        d = df_median.loc[:,[t,'cost']]
        map_dict = TwoDimensionsPD(d)
        fig, ax = plt.subplots()
        ax.scatter(df_median['cost'], df_median[t])
        ax.scatter(df_median.loc[map_dict.keys(),'cost'], df_median.loc[map_dict.keys(),t],c='orange')
        plt.plot(df_median.loc[m,'cost'],df_median.loc[m,t],'yo',markersize=15)

# %% [markdown]
# ### Check how many of the non-pareto model can solve multiple tasks

# %%
count_m = df_median.iloc[:,:-1].T.count()
print(count_m.head())
count_max = df_max.iloc[:,:-1].T.count()
print(count_max.head())
# Out:
# M8     4
# M12    4
# M10    3
# M3     4
# M4     3
# dtype: int64
# M0    3
# M9    2
# M7    3
# M2    3
# M8    3
# dtype: int64

# %%
def multi_task_ratio(df,count_m):
    count_mult = 0
    count = 0
    predicates = list(df.loc[:,'predicate'])
    for predicate in predicates:
        predicate = predicate.split('|')
        for p in predicate:
            t, m = p.split('.')
            count += 1
            if count_m[m] > 1:
                count_mult += 1
    print(count,count_mult,round(count_mult/count,4))

multi_task_ratio(df_np_median,count_m)
multi_task_ratio(df_np_max,count_max)
# Out:
# 385 370 0.961
# 430 430 1.0

# %% [markdown]
# ## Runtime

# %%
df = pd.read_csv('simulation/synthesize_summary.csv',index_col=0)
df.head()
# Out:
#       M    N      time
# 0   400   40  0.038071
# 1   400   80  0.051637
# 2   400  100  0.064565
# 3   400  200  0.100106
# 4  1600   40  0.140359

# %%
fig = plt.figure()
for N in [20,40,80,100]:
    plt.plot(df.loc[df['N'] == N,'M'], df.loc[df['N'] == N,'time'],\
             label='N='+str(N))
    plt.title('Synthesis Scalability')
    plt.xlabel("#Model")
    plt.ylabel("time(s)")
    plt.legend(loc='lower right')

# %%
fig=plt.figure()
for N in [40,80,100,200]:
#     for M in [100 * 4 ** i for i in range(1,6)]:
    plt.plot(df.loc[df['N'] == N,'M'], df.loc[df['N'] == N,'time'],\
            label='N='+str(N))
plt.title('Synthesis Scalability')
plt.xlabel("#Model")
plt.ylabel("time(s)")
plt.legend(loc='lower right')

# %% [markdown]
# ### Optimiztion runtime

# %%
path = 'simulation/run_summary.csv'
df_run = pd.read_csv(path,index_col=0)
df_run.head()
# Out:
#        M     N  #query      time
# 0  200.0  20.0    50.0  0.625579
# 1  200.0  20.0   100.0  1.793187
# 2  200.0  20.0   150.0  2.776522
# 3  200.0  20.0   200.0  3.445141
# 4  200.0  40.0    50.0  0.946925

# %%
N_range = [20,40,80]
M = 200
df_run_200 = df_run.loc[df_run['M']==M,:]
legend_plot(N_range,df_run_200,'N','M=200')

# %%
def legend_plot(_range, df,label,knob):
    fig=plt.figure()
    for N in _range:
        plt.plot(df.loc[df[label] == N,'#query'], df.loc[df[label] == N,'time'],\
                 label=label+'='+str(N),linestyle='--',marker='o')
    plt.title('Optimization Scalability ('+knob+')')
    plt.xticks(df.loc[df[label]==N,'#query'])
    plt.xlabel("#Query")
    plt.ylabel("time(s)")
    plt.legend()
    
M_range = [100*(2**i) for i in range(1,5)]
print(M_range)
N = 40
df_run_N_40 = df_run.loc[df_run['N']==N,:]
legend_plot(M_range,df_run_N_40,'M','N=40')
# Out:
# [200, 400, 800, 1600]

# %%
def legend_2d_plot(M_range,N_range, df):
    fig=plt.figure()
    for M in M_range:
        df_run_M = df_run.loc[df_run['M']==M,:]
        for N in N_range:
            plt.plot(df_run_M.loc[df_run_M['N'] == N,'#query'], df_run_M.loc[df_run_M['N'] == N,'time'],\
                 label='M='+str(M)+',N='+str(N),linestyle='--',marker='o')
    plt.title('Optimization Scalability')
    plt.xticks(df_run_M.loc[df_run_M['N']==N,'#query'])
    plt.xlabel("#Query")
    plt.ylabel("time(s)")
    plt.legend(bbox_to_anchor=(1.05, 1))

M_range = [100*(2**i) for i in range(1,5)]
N_range = [20,40,80]
legend_2d_plot(M_range,N_range, df_run)
